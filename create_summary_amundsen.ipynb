# %%
from create_percent_diff_summary import invert_dotson_fcn, invert_pig_fcn, invert_thwaites_fcn, invert_amundsen_fcn,eval_models, collect_r2_scores, plot_r2_heatmap_with_symbols, replace_features_with_symbols
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.colorbar as colorbar
import os
import sys
import copy
import pickle
import pandas as pd
import firedrake
from scipy.spatial import cKDTree
# Out:
# 2025-06-24 19:53:07.157144: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-24 19:53:08.720653: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-24 19:53:09.476061: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750794790.325622    1253 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750794790.547875    1253 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-24 19:53:12.178924: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
inv_amundsen = invert_amundsen_fcn()
df = inv_amundsen.get_dataframe(inv_amundsen.inverse_u)
# Out:
# Reading local outline
# Creating mesh
# Reading mesh
# Reading bedmachine data
# Initializing function spaces
# Initializing 3d function spaces
# Initializing fields
# Defining friction law
# Setting ramp power to :  1
# Initializing heat transport
# Reading velocity from measures database
# C0 is constant: 0.01
# Defining friction law
# Defining friction law
# using englacial temperature for rate factor
# Geophysics data imported
# Using loss function without sigma
#
# Truncated CG Trust-Region Solver
#   iter  value          gnorm          snorm          delta          #fval     #grad     tr_flag   iterCG    flagCG
#   0     1.489273e+08   4.828976e+03                  2.885634e+04
#   1     5.951057e+07   2.114047e+03   2.885634e+04   7.214086e+04   3         2         0         2         2
#   2     5.951057e+07   2.114047e+03   7.214086e+04   4.508804e+03   4         2         2         2         2
#   3     5.104125e+07   1.663927e+03   4.508804e+03   1.127201e+04   5         3         0         1         3
#   4     3.574796e+07   1.083941e+03   1.127201e+04   2.818002e+04   6         4         0         1         3
#   5     1.633169e+07   4.380025e+02   2.818002e+04   7.045006e+04   7         5         0         2         3
#   6     4.123540e+06   1.093680e+02   7.045006e+04   1.761251e+05   8         6         0         3         2
#   7     4.123540e+06   1.093680e+02   1.761251e+05   1.100782e+04   9         6         2         3         2
#   8     3.160605e+06   7.042672e+01   1.100782e+04   2.751955e+04   10        7         0         1         3
#   9     1.908736e+06   3.128624e+01   2.751955e+04   6.879889e+04   11        8         0         1         3
#   10    7.386344e+05   1.066026e+01   6.879889e+04   1.719972e+05   12        9         0         2         3
#   11    7.386344e+05   1.066026e+01   1.719972e+05   1.074983e+04   13        9         2         4         2
#   12    6.367705e+05   8.502969e+00   1.074983e+04   2.687456e+04   14        10        0         1         3
#   13    4.548353e+05   5.526150e+00   2.687456e+04   6.718641e+04   15        11        0         1         3
#   14    2.117315e+05   2.393099e+00   6.718641e+04   1.679660e+05   16        12        0         1         3
#   15    2.117315e+05   2.393099e+00   1.679660e+05   1.049788e+04   17        12        2         2         2
#   16    1.881527e+05   2.077546e+00   1.049788e+04   2.624469e+04   18        13        0         1         3
#   17    1.415350e+05   1.526473e+00   2.624469e+04   6.561173e+04   19        14        0         1         3
#   18    7.222343e+04   7.954808e-01   6.561173e+04   1.640293e+05   20        15        0         1         3
#   19    3.266447e+04   2.397568e+00   1.640293e+05   1.640293e+05   21        16        0         3         2
#   20    3.266447e+04   2.397568e+00   1.640293e+05   1.025183e+04   22        16        2         3         2
#   21    2.209970e+04   4.895358e-01   1.025183e+04   2.562958e+04   23        17        0         2         3
#   22    2.209970e+04   4.895358e-01   2.562958e+04   1.601849e+03   24        17        2         2         3
#   23    2.144317e+04   3.820817e-01   1.601849e+03   4.004622e+03   25        18        0         1         3
#   24    2.011966e+04   2.908822e-01   4.004622e+03   1.001156e+04   26        19        0         1         3
#   25    1.946612e+04   7.428021e-01   1.001156e+04   1.001156e+04   27        20        0         2         3
#   26    1.946612e+04   7.428021e-01   1.001156e+04   1.269160e+03   28        20        2         1         3
#   27    1.861778e+04   5.931076e-01   1.269160e+03   3.172900e+03   29        21        0         1         3
#   28    1.805124e+04   3.371905e-01   3.172900e+03   3.172900e+03   30        22        0         2         3
#   29    1.801812e+04   5.566674e-01   3.172900e+03   3.172900e+03   31        23        0         1         3
#   30    1.747371e+04   3.589204e-01   3.172900e+03   3.172900e+03   32        24        0         2         3
#   31    1.734141e+04   5.659191e-01   3.172900e+03   3.172900e+03   33        25        0         2         3
#   32    1.673282e+04   3.307272e-01   3.172900e+03   3.172900e+03   34        26        0         2         3
#   33    1.627824e+04   2.784039e-01   3.172900e+03   3.172900e+03   35        27        0         2         3
#   34    1.583085e+04   1.493034e-01   3.172900e+03   7.932250e+03   36        28        0         2         3
#   35    1.521765e+04   4.532769e-01   7.932250e+03   1.983062e+04   37        29        0         2         3
#   36    1.521765e+04   4.532769e-01   1.983062e+04   1.239414e+03   38        29        2         3         3
#   37    1.521765e+04   4.532769e-01   1.239414e+03   2.314616e+02   39        29        2         1         3
#   38    1.512135e+04   3.798112e-01   2.314616e+02   5.786540e+02   40        30        0         1         3
#   39    1.495078e+04   2.200414e-01   5.786540e+02   1.446635e+03   41        31        0         1         3
#   40    1.476356e+04   1.182651e-01   1.446635e+03   3.616587e+03   42        32        0         2         3
#   41    1.452035e+04   3.042206e-01   3.616587e+03   9.041469e+03   43        33        0         2         3
#   42    1.352123e+04   1.452917e-01   9.041469e+03   2.260367e+04   44        34        0         3         3
#   43    1.164655e+04   1.237139e-01   2.260367e+04   5.650918e+04   45        35        0         3         3
#   44    1.067166e+04   5.077007e-01   5.650918e+04   5.650918e+04   46        36        0         4         2
#   45    1.067166e+04   5.077007e-01   5.650918e+04   3.531824e+03   47        36        2         4         2
#   46    9.742447e+03   1.579370e-01   3.531824e+03   8.829559e+03   48        37        0         3         3
#   47    9.597587e+03   4.974490e-01   8.829559e+03   8.829559e+03   49        38        0         2         3
#   48    8.818001e+03   4.993768e-01   8.829559e+03   8.829559e+03   50        39        0         4         2
#   49    8.532464e+03   1.250823e-01   8.829559e+03   8.829559e+03   51        40        0         4         2
#   50    8.378271e+03   3.046397e-01   8.829559e+03   8.829559e+03   52        41        0         2         3
#   51    7.981178e+03   1.420626e-01   8.829559e+03   8.829559e+03   53        42        0         4         3
#   52    7.588873e+03   1.811039e-01   8.829559e+03   8.829559e+03   54        43        0         5         3
#   53    7.487668e+03   1.317670e-01   8.829559e+03   8.829559e+03   55        44        0         4         3
#   54    7.487668e+03   1.317670e-01   8.829559e+03   2.207390e+03   56        44        2         1         3
#   55    7.282177e+03   1.146959e-01   2.207390e+03   2.207390e+03   57        45        0         1         3
#   56    7.186737e+03   4.500841e-02   2.207390e+03   5.518474e+03   58        46        0         3         3
#   57    7.065114e+03   1.519821e-01   5.518474e+03   1.379619e+04   59        47        0         3         3
#   58    6.683013e+03   8.584090e-02   1.379619e+04   3.449047e+04   60        48        0         4         3
#   59    6.264649e+03   2.455616e-01   3.449047e+04   3.449047e+04   61        49        0         6         3
#   60    6.264649e+03   2.455616e-01   3.449047e+04   4.122909e+03   62        49        2         5         2
#   61    5.934454e+03   1.230000e-01   4.122909e+03   1.030727e+04   63        50        0         3         3
#   62    5.934454e+03   1.230000e-01   1.030727e+04   6.442046e+02   64        50        2         4         3
#   63    5.893262e+03   5.614678e-02   6.442046e+02   1.610511e+03   65        51        0         2         3
#   64    5.834642e+03   7.425684e-02   1.610511e+03   4.026279e+03   66        52        0         2         3
#   65    5.773181e+03   2.473438e-01   4.026279e+03   4.026279e+03   67        53        0         2         3
#   66    5.604131e+03   5.262988e-02   4.026279e+03   1.006570e+04   68        54        0         4         3
#   67    5.463636e+03   9.621541e-02   1.006570e+04   1.006570e+04   69        55        0         5         3
#   68    5.275041e+03   5.553479e-02   1.006570e+04   1.006570e+04   70        56        0         6         3
#   69    5.112267e+03   5.835365e-02   1.006570e+04   2.516424e+04   71        57        0         6         3
#   70    5.112267e+03   5.835365e-02   2.516424e+04   1.572765e+03   72        57        2         6         3
#   71    5.072938e+03   5.116651e-02   1.572765e+03   1.572765e+03   73        58        0         3         3
#   72    5.038919e+03   5.291765e-02   1.572765e+03   3.931913e+03   74        59        0         3         3
#   73    4.979458e+03   5.386529e-02   3.931913e+03   9.829782e+03   75        60        0         4         3
#   74    4.845752e+03   7.962713e-02   9.829782e+03   2.457445e+04   76        61        0         5         3
#   75    4.845752e+03   7.962713e-02   2.457445e+04   1.535903e+03   77        61        2         3         2
#   76    4.772255e+03   9.150963e-02   1.535903e+03   3.839758e+03   78        62        0         2         3
#   77    4.772255e+03   9.150963e-02   3.839758e+03   2.399849e+02   79        62        2         2         2
#   78    4.755486e+03   6.141040e-02   2.399849e+02   5.999623e+02   80        63        0         1         3
#   79    4.720949e+03   6.373673e-02   5.999623e+02   1.499906e+03   81        64        0         1         3
#   80    4.708810e+03   1.750188e-01   1.499906e+03   1.499906e+03   82        65        0         2         3
#   81    4.643785e+03   7.708276e-02   1.499906e+03   3.749764e+03   83        66        0         3         3
#   82    4.567604e+03   7.453229e-02   3.749764e+03   9.374410e+03   84        67        0         3         3
#   83    4.448922e+03   1.510802e-01   9.374410e+03   2.343603e+04   85        68        0         4         3
#   84    4.362458e+03   1.806836e-01   2.343603e+04   2.343603e+04   86        69        0         7         3
#   85    4.101123e+03   1.328651e-01   2.343603e+04   2.343603e+04   87        70        0         9         3
#   86    4.101123e+03   1.328651e-01   2.343603e+04   1.464752e+03   88        70        2         7         3
#   87    4.002266e+03   6.766885e-02   1.464752e+03   3.661879e+03   89        71        0         2         3
#   88    3.916642e+03   4.112108e-02   3.661879e+03   9.154698e+03   90        72        0         4         3
#   89    3.820592e+03   6.135675e-02   9.154698e+03   2.288674e+04   91        73        0         6         3
#   90    3.797020e+03   1.110725e-01   2.288674e+04   2.288674e+04   92        74        0         7         3
#   91    3.668312e+03   1.834170e-01   2.288674e+04   2.288674e+04   93        75        0         9         3
#   92    3.668312e+03   1.834170e-01   2.288674e+04   1.430421e+03   94        75        2         8         3
#   93    3.592574e+03   5.118033e-02   1.430421e+03   3.576054e+03   95        76        0         3         3
#   94    3.522519e+03   5.619509e-02   3.576054e+03   8.940134e+03   96        77        0         4         3
#   95    3.441898e+03   4.963463e-02   8.940134e+03   8.940134e+03   97        78        0         6         3
#   96    3.416977e+03   4.362009e-02   8.940134e+03   8.940134e+03   98        79        0         7         3
#   97    3.397158e+03   4.565389e-02   8.940134e+03   8.940134e+03   99        80        0         6         3
#   98    3.377396e+03   4.031931e-02   8.940134e+03   8.940134e+03   100       81        0         8         3
#   99    3.338036e+03   3.589457e-02   8.940134e+03   8.940134e+03   101       82        0         5         2
#   100   3.338036e+03   3.589457e-02   8.940134e+03   5.587584e+02   102       82        2         5         3
#   101   3.323065e+03   3.553294e-02   5.587584e+02   1.396896e+03   103       83        0         1         3
#   102   3.297063e+03   4.043716e-02   1.396896e+03   3.492240e+03   104       84        0         2         3
#   103   3.277445e+03   1.972338e-02   3.492240e+03   3.492240e+03   105       85        0         5         3
#   104   3.264112e+03   1.862768e-02   3.492240e+03   3.492240e+03   106       86        0         5         3
#   105   3.256001e+03   2.369083e-02   3.492240e+03   3.492240e+03   107       87        0         4         3
#   106   3.256001e+03   2.369083e-02   3.492240e+03   2.182650e+02   108       87        2         3         3
#   107   3.251252e+03   2.079162e-02   2.182650e+02   5.456625e+02   109       88        0         1         3
#   108   3.243234e+03   3.684722e-02   5.456625e+02   1.364156e+03   110       89        0         1         3
#   109   3.233485e+03   1.517051e-02   1.364156e+03   1.364156e+03   111       90        0         3         3
#   110   3.224730e+03   1.503423e-02   1.364156e+03   3.410391e+03   112       91        0         5         3
#   111   3.206531e+03   2.352726e-02   3.410391e+03   8.525976e+03   113       92        0         5         3
#   112   3.167532e+03   5.922865e-02   8.525976e+03   2.131494e+04   114       93        0         5         3
#   113   3.137338e+03   2.340362e-01   2.131494e+04   2.131494e+04   115       94        0         9         3
#   114   3.137338e+03   2.340362e-01   2.131495e+04   1.332184e+03   116       94        2         11        3
#   115   3.051185e+03   3.351147e-02   1.332184e+03   3.330460e+03   117       95        0         4         3
#   116   3.025626e+03   2.857003e-02   3.330460e+03   3.330460e+03   118       96        0         4         3
#   117   3.003826e+03   2.868459e-02   3.330460e+03   8.326149e+03   119       97        0         6         3
#   118   3.000223e+03   1.657692e-01   8.326149e+03   8.326149e+03   120       98        0         7         3
#   119   2.963025e+03   2.602890e-02   8.326149e+03   8.326149e+03   121       99        0         8         3
#   120   2.944075e+03   7.121984e-02   8.326149e+03   8.326149e+03   122       100       0         6         3
#   121   2.937192e+03   3.022077e-02   8.326149e+03   8.326149e+03   123       101       0         7         3
#   122   2.937192e+03   3.022077e-02   8.326149e+03   5.203843e+02   124       101       2         4         3
#   123   2.926952e+03   3.014775e-02   5.203843e+02   1.300961e+03   125       102       0         2         3
#   124   2.911674e+03   6.219220e-02   1.300961e+03   3.252402e+03   126       103       0         2         3
#   125   2.902836e+03   3.976953e-02   3.252402e+03   3.252402e+03   127       104       0         3         3
#   126   2.886615e+03   2.309742e-02   3.252402e+03   3.252402e+03   128       105       0         6         3
#   127   2.871116e+03   1.104326e-02   3.252402e+03   3.252402e+03   129       106       0         7         3
#   128   2.868001e+03   1.854538e-02   3.252402e+03   3.252402e+03   130       107       0         5         3
#   129   2.848205e+03   1.073989e-02   3.252402e+03   3.252402e+03   131       108       0         7         3
#   130   2.840011e+03   1.702156e-02   3.252402e+03   3.252402e+03   132       109       0         6         3
#   131   2.823797e+03   1.336698e-02   3.252402e+03   8.131005e+03   133       110       0         7         3
#   132   2.808231e+03   7.248555e-02   8.131005e+03   8.131005e+03   134       111       0         7         3
#   133   2.772407e+03   2.345004e-02   8.131005e+03   2.032751e+04   135       112       0         8         3
#   134   2.772407e+03   2.345004e-02   2.032751e+04   1.270469e+03   136       112       2         11        3
#   135   2.762784e+03   1.051696e-02   1.270469e+03   3.176174e+03   137       113       0         4         3
#   136   2.754899e+03   1.715211e-02   3.176174e+03   7.940434e+03   138       114       0         6         3
#   137   2.740967e+03   6.897408e-02   7.940434e+03   7.940434e+03   139       115       0         9         3
#   138   2.711130e+03   1.363378e-02   7.940434e+03   1.985109e+04   140       116       0         10        3
#   139   2.711130e+03   1.363378e-02   1.985109e+04   1.240693e+03   141       116       2         12        3
#   140   2.704043e+03   7.998413e-03   1.240693e+03   3.101732e+03   142       117       0         4         3
#   141   2.696706e+03   1.929108e-02   3.101732e+03   7.754330e+03   143       118       0         6         3
#   142   2.682796e+03   3.679060e-02   7.754330e+03   1.938583e+04   144       119       0         8         3
#   143   2.646946e+03   3.736907e-02   1.938583e+04   4.846457e+04   145       120       0         11        3
#   144   2.617086e+03   3.238705e-02   4.846457e+04   4.846457e+04   146       121       0         19        3
#   145   2.617086e+03   3.238705e-02   4.846455e+04   3.029035e+03   147       121       2         14        3
#   146   2.592150e+03   2.005607e-02   3.029035e+03   7.572588e+03   148       122       0         5         3
#   147   2.572314e+03   3.125624e-02   7.572588e+03   7.572588e+03   149       123       0         6         3
#   148   2.551557e+03   1.765602e-02   7.572588e+03   7.572588e+03   150       124       0         11        3
#   149   2.551557e+03   1.765602e-02   7.572588e+03   4.732868e+02   151       124       2         11        3
#   150   2.546531e+03   1.802316e-02   4.732868e+02   1.183217e+03   152       125       0         2         3
#   151   2.542008e+03   8.698138e-03   1.183217e+03   1.183217e+03   153       126       0         5         3
#   152   2.538547e+03   7.539553e-03   1.183217e+03   2.958042e+03   154       127       0         5         3
#   153   2.534595e+03   5.428273e-03   2.958042e+03   7.395106e+03   155       128       0         6         3
#   154   2.527266e+03   8.045551e-03   7.395106e+03   1.848776e+04   156       129       0         10        3
#   155   2.510559e+03   3.337052e-02   1.848769e+04   4.621941e+04   157       130       0         14        3
#   156   2.499606e+03   1.578880e-02   2.820992e+04   4.621941e+04   158       131       0         20        1
#   157   2.499606e+03   1.578880e-02   4.621941e+04   2.888713e+03   159       131       2         10        2
#   158   2.485233e+03   1.045877e-02   2.888713e+03   7.221783e+03   160       132       0         5         3
#   159   2.484178e+03   1.139699e-02   7.221783e+03   7.221783e+03   161       133       0         11        3
#   160   2.480595e+03   1.118846e-02   7.221783e+03   7.221783e+03   162       134       0         9         3
#   161   2.480595e+03   1.118846e-02   7.221783e+03   1.805446e+03   163       135       0         10        3
#   162   2.474500e+03   7.489204e-03   1.805446e+03   1.805446e+03   164       136       0         5         3
#   163   2.470757e+03   5.423217e-03   1.805446e+03   4.513614e+03   165       137       0         7         3
#   164   2.467638e+03   2.532979e-03   4.513614e+03   4.513614e+03   166       138       0         11        3
#   165   2.465090e+03   4.085923e-03   4.513614e+03   4.513614e+03   167       139       0         11        3
#   166   2.462731e+03   2.778604e-03   4.513614e+03   4.513614e+03   168       140       0         12        3
#   167   2.460921e+03   5.039835e-03   4.513614e+03   4.513614e+03   169       141       0         10        3
#   168   2.459703e+03   4.791818e-03   4.513614e+03   4.513614e+03   170       142       0         11        3
#   169   2.456558e+03   4.319939e-03   4.513614e+03   4.513614e+03   171       143       0         12        3
#   170   2.453062e+03   3.973339e-03   4.513614e+03   4.513614e+03   172       144       0         12        3
#   171   2.449997e+03   3.497399e-03   4.513614e+03   4.513614e+03   173       145       0         12        3
#   172   2.446986e+03   2.378948e-03   4.513614e+03   4.513614e+03   174       146       0         13        3
#   173   2.445438e+03   2.456588e-03   4.513614e+03   4.513614e+03   175       147       0         12        3
#   174   2.445438e+03   2.456588e-03   4.513614e+03   4.692910e+02   176       147       2         8         3
#   175   2.444833e+03   4.753290e-03   4.692910e+02   1.173227e+03   177       148       0         3         3
#   176   2.443872e+03   4.988137e-03   1.173227e+03   1.173227e+03   178       149       0         6         3
#   177   2.442864e+03   2.211839e-03   1.173227e+03   2.933069e+03   179       150       0         8         3
#   178   2.441552e+03   2.700057e-03   2.933069e+03   7.332672e+03   180       151       0         10        3
#   179   2.437807e+03   4.574078e-03   7.332672e+03   1.833168e+04   181       152       0         13        3
#   180   2.432383e+03   6.206689e-03   1.833168e+04   1.833168e+04   182       153       0         19        3
#   181   2.432383e+03   6.206689e-03   1.833168e+04   1.145730e+03   183       153       2         10        2
#   182   2.429329e+03   6.291959e-03   1.145730e+03   2.864325e+03   184       154       0         4         3
#   183   2.427563e+03   5.519336e-03   2.864325e+03   2.864325e+03   185       155       0         7         3
#   184   2.425819e+03   2.205778e-03   2.864325e+03   2.864325e+03   186       156       0         12        3
#   185   2.424264e+03   1.864485e-03   2.864325e+03   7.160812e+03   187       157       0         14        3
#   186   2.422977e+03   5.746840e-03   7.160813e+03   7.160812e+03   188       158       0         17        3
#   187   2.422977e+03   5.746840e-03   7.160812e+03   4.475508e+02   189       158       2         9         3
#   188   2.422363e+03   5.595152e-03   4.475508e+02   1.118877e+03   190       159       0         3         3
#   189   2.421431e+03   3.267037e-03   1.118877e+03   1.118877e+03   191       160       0         5         3
#   190   2.420595e+03   1.761090e-03   1.118877e+03   2.797192e+03   192       161       0         8         3
#   191   2.419729e+03   2.896866e-03   2.797192e+03   6.992981e+03   193       162       0         12        3
#   192   2.417575e+03   2.008799e-03   6.992981e+03   1.748245e+04   194       163       0         15        3
#   193   2.415772e+03   1.838857e-03   7.281662e+03   1.748245e+04   195       164       0         20        1
#   194   2.413861e+03   2.139422e-03   7.078469e+03   1.748245e+04   196       165       0         20        1
#   195   2.413861e+03   2.139422e-03   1.748245e+04   1.092653e+03   197       165       2         10        3
#   196   2.412999e+03   2.072596e-03   1.092653e+03   2.731633e+03   198       166       0         6         3
#   197   2.412447e+03   2.683269e-03   2.731633e+03   2.731633e+03   199       167       0         9         3
#   198   2.411342e+03   1.396826e-03   2.731633e+03   2.731633e+03   200       168       0         15        3
#   199   2.410667e+03   1.804472e-03   2.731632e+03   2.731633e+03   201       169       0         14        3
#   200   2.409915e+03   4.424967e-03   2.731627e+03   2.731633e+03   202       170       0         15        3
#   201   2.409213e+03   1.487960e-03   2.731632e+03   2.731633e+03   203       171       0         15        3
#   202   2.408411e+03   1.519158e-03   2.731633e+03   2.731633e+03   204       172       0         16        3
#   203   2.407697e+03   1.616318e-03   2.731633e+03   2.731633e+03   205       173       0         16        3
#   204   2.406859e+03   1.744673e-03   2.731633e+03   2.731633e+03   206       174       0         16        3
#   205   2.406081e+03   1.776243e-03   2.731629e+03   2.731633e+03   207       175       0         14        3
#   206   2.405184e+03   1.286317e-03   2.731633e+03   6.829083e+03   208       176       0         13        3
#   207   2.401316e+03   5.238738e-03   6.829083e+03   1.707271e+04   209       177       0         14        3
#   208   2.401316e+03   5.238738e-03   1.707271e+04   1.067044e+03   210       177       2         10        3
#   209   2.398934e+03   5.965081e-03   1.067044e+03   2.667610e+03   211       178       0         4         3
#   210   2.397818e+03   6.303907e-03   2.667610e+03   2.667610e+03   212       179       0         6         3
#   211   2.393606e+03   2.406239e-03   2.667610e+03   6.669026e+03   213       180       0         11        3
#   212   2.393606e+03   2.406239e-03   6.669026e+03   4.168141e+02   214       180       2         12        3
#   213   2.393192e+03   1.834700e-03   4.168141e+02   1.042035e+03   215       181       0         4         3
#   214   2.392695e+03   4.101262e-03   1.042035e+03   2.605088e+03   216       182       0         6         3
#   215   2.391641e+03   2.537867e-03   2.605088e+03   2.605088e+03   217       183       0         10        3
#   216   2.390254e+03   1.990878e-03   2.605088e+03   6.512721e+03   218       184       0         12        3
#   217   2.389617e+03   6.335496e-03   6.512721e+03   6.512721e+03   219       185       0         15        3
#   218   2.386702e+03   3.750569e-03   6.512721e+03   1.628180e+04   220       186       0         17        3
#   219   2.385113e+03   1.500825e-03   3.539174e+03   4.070450e+04   221       187       0         20        1
#   220   2.384046e+03   1.424041e-03   6.005546e+03   1.017613e+05   222       188       0         20        1
#   221   2.383031e+03   1.324877e-03   3.707843e+03   1.017613e+05   223       189       0         20        1
#   222   2.382140e+03   1.626704e-03   4.941902e+03   1.017613e+05   224       190       0         20        1
#   223   2.381339e+03   8.340796e-04   2.849325e+03   2.544032e+05   225       191       0         20        1
#   224   2.380367e+03   5.524983e-03   6.616240e+03   6.360079e+05   226       192       0         20        1
#   225   2.380367e+03   5.524983e-03   6.360079e+05   3.975049e+04   227       192       2         19        2
#   226   2.380367e+03   5.524983e-03   3.975049e+04   2.484406e+03   228       192       2         18        3
#   227   2.379010e+03   3.831365e-03   2.484406e+03   6.211014e+03   229       193       0         11        3
#   228   2.379010e+03   3.831365e-03   6.211014e+03   3.881884e+02   230       193       2         11        3
#   229   2.378666e+03   1.888330e-03   3.881884e+02   9.704710e+02   231       194       0         5         3
#   230   2.378070e+03   3.619206e-03   9.704710e+02   2.426178e+03   232       195       0         6         3
#   231   2.378070e+03   3.619206e-03   2.426178e+03   1.516361e+02   233       195       2         8         2
#   232   2.377832e+03   2.683143e-03   1.516361e+02   3.790902e+02   234       196       0         2         3
#   233   2.377503e+03   1.868130e-03   3.790902e+02   9.477256e+02   235       197       0         5         3
#   234   2.376881e+03   4.811769e-03   9.477256e+02   2.369314e+03   236       198       0         6         3
#   235   2.376881e+03   4.811769e-03   2.369314e+03   1.480821e+02   237       198       2         8         3
#   236   2.376577e+03   2.612155e-03   1.480821e+02   3.702053e+02   238       199       0         3         3
#   237   2.376244e+03   1.620062e-03   3.702053e+02   9.255133e+02   239       200       0         5         3
#   238   2.375610e+03   4.608064e-03   9.255133e+02   9.255133e+02   240       201       0         6         3
#   239   2.375473e+03   4.266438e-03   9.255133e+02   9.255133e+02   241       202       0         7         3
#   240   2.374625e+03   2.868969e-03   9.255133e+02   2.313783e+03   242       203       0         9         3
#   241   2.373857e+03   7.062779e-03   2.313783e+03   2.313783e+03   243       204       0         10        3
#   242   2.373857e+03   7.062779e-03   2.313783e+03   1.446114e+02   244       204       2         11        3
#   243   2.373621e+03   3.131130e-03   1.446114e+02   3.615286e+02   245       205       0         3         3
#   244   2.373457e+03   7.587331e-04   3.615286e+02   9.038216e+02   246       206       0         6         3
#   245   2.373457e+03   7.587331e-04   9.038216e+02   5.648885e+01   247       206       2         7         3
#   246   2.373435e+03   1.485027e-03   5.648885e+01   1.412221e+02   248       207       0         2         3
#   247   2.373394e+03   1.252485e-03   1.412221e+02   1.412221e+02   249       208       0         4         3
#   248   2.373339e+03   1.004874e-03   1.412221e+02   3.530553e+02   250       209       0         4         3
#   249   2.373255e+03   1.086493e-03   3.530553e+02   8.826382e+02   251       210       0         6         3
#   250   2.373038e+03   1.641385e-03   8.826382e+02   2.206596e+03   252       211       0         8         3
#   251   2.372621e+03   2.866574e-03   2.206596e+03   5.516489e+03   253       212       0         11        3
#   252   2.372621e+03   2.866574e-03   5.516489e+03   3.447806e+02   254       212       2         19        3
#   253   2.372424e+03   7.567485e-04   3.447806e+02   8.619514e+02   255       213       0         7         3
#   254   2.372300e+03   7.555947e-04   8.619514e+02   8.619514e+02   256       214       0         9         3
#   255   2.372282e+03   1.589507e-03   8.619514e+02   8.619514e+02   257       215       0         9         3
#   256   2.372015e+03   7.086938e-04   8.619514e+02   2.154879e+03   258       216       0         12        3
#   257   2.371701e+03   1.959221e-03   2.154879e+03   5.387196e+03   259       217       0         12        3
#   258   2.371314e+03   1.623202e-03   5.387196e+03   5.387196e+03   260       218       0         18        3
#   259   2.370839e+03   1.102738e-03   2.833026e+03   5.387196e+03   261       219       0         20        1
#   260   2.370839e+03   1.102738e-03   5.387196e+03   3.366998e+02   262       219       2         17        3
#   261   2.370656e+03   1.319396e-03   3.366998e+02   8.417494e+02   263       220       0         4         3
#   262   2.370410e+03   4.698282e-04   8.417494e+02   2.104374e+03   264       221       0         9         3
#   263   2.370219e+03   7.069368e-04   2.104374e+03   5.260934e+03   265       222       0         15        3
#   264   2.369945e+03   7.042636e-04   2.707339e+03   1.315233e+04   266       223       0         20        1
#   265   2.369707e+03   5.533136e-04   1.892445e+03   3.288084e+04   267       224       0         20        1
#   266   2.369540e+03   7.737810e-04   2.298475e+03   3.288084e+04   268       225       0         20        1
#   267   2.369350e+03   6.746049e-04   1.665644e+03   3.288084e+04   269       226       0         20        1
#   268   2.369350e+03   6.746049e-04   3.288084e+04   2.055052e+03   270       226       2         9         2
#   269   2.369350e+03   6.746049e-04   2.055052e+03   1.284408e+02   271       226       2         8         3
#   270   2.369324e+03   5.610876e-04   1.284408e+02   3.211019e+02   272       227       0         5         3
#   271   2.369324e+03   5.610876e-04   3.211019e+02   2.006887e+01   273       227       2         6         2
#   272   2.369317e+03   4.912051e-04   2.006887e+01   5.017218e+01   274       228       0         2         3
#   273   2.369310e+03   8.567823e-04   5.017218e+01   1.254304e+02   275       229       0         2         3
#   274   2.369291e+03   5.987895e-04   1.254304e+02   1.254304e+02   276       230       0         6         3
#   275   2.369273e+03   3.615481e-04   1.254304e+02   3.135761e+02   277       231       0         7         3
#   276   2.369243e+03   5.453704e-04   3.135761e+02   7.839402e+02   278       232       0         8         3
#   277   2.369184e+03   6.305086e-04   7.839402e+02   1.959851e+03   279       233       0         11        3
#   278   2.369020e+03   6.513986e-04   1.959851e+03   4.899627e+03   280       234       0         15        3
#   279   2.368848e+03   1.000676e-03   2.229456e+03   4.899627e+03   281       235       0         20        1
#   280   2.368848e+03   1.000676e-03   4.899627e+03   3.062267e+02   282       235       2         19        3
#   281   2.368769e+03   2.423294e-04   3.062267e+02   7.655666e+02   283       236       0         9         3
#   282   2.368701e+03   5.266149e-04   7.655666e+02   1.913917e+03   284       237       0         10        3
#   283   2.368564e+03   9.700065e-04   1.913917e+03   4.784792e+03   285       238       0         18        3
#   284   2.368421e+03   5.364173e-04   1.585276e+03   1.196198e+04   286       239       0         20        1
#   285   2.368299e+03   4.416431e-04   1.507810e+03   2.990495e+04   287       240       0         20        1
#   286   2.368191e+03   4.116536e-04   1.364411e+03   7.476237e+04   288       241       0         20        1
#   287   2.368091e+03   3.909952e-04   1.368852e+03   1.869059e+05   289       242       0         20        1
#   288   2.367996e+03   3.724766e-04   1.283350e+03   4.672648e+05   290       243       0         20        1
#   289   2.367907e+03   3.621605e-04   1.280026e+03   1.168162e+06   291       244       0         20        1
#   290   2.367821e+03   3.562480e-04   1.207375e+03   2.920405e+06   292       245       0         20        1
#   291   2.367742e+03   3.548004e-04   1.222587e+03   7.301012e+06   293       246       0         20        1
#   292   2.367664e+03   3.397817e-04   1.128718e+03   1.825253e+07   294       247       0         20        1
#   293   2.367594e+03   3.491420e-04   1.212856e+03   4.563133e+07   295       248       0         20        1
#   294   2.367522e+03   3.154815e-04   1.035416e+03   1.140783e+08   296       249       0         20        1
#   295   2.367460e+03   3.505754e-04   1.278437e+03   1.140783e+08   297       250       0         20        1
#   296   2.367388e+03   2.884003e-04   9.410131e+02   2.851958e+08   298       251       0         20        1
#   297   2.367330e+03   3.461832e-04   1.361397e+03   2.851958e+08   299       252       0         20        1
#   298   2.367260e+03   2.686165e-04   8.825908e+02   7.129895e+08   300       253       0         20        1
#   299   2.367203e+03   3.356903e-04   1.375693e+03   7.129895e+08   301       254       0         20        1
#   300   2.367138e+03   2.573140e-04   8.358029e+02   1.782474e+09   302       255       0         20        1
# Optimization Terminated with Status: Iteration Limit Exceeded

# %%
inv_loss_amundsen = firedrake.assemble(inv_amundsen.loss_functional_nosigma(inv_amundsen.inverse_u))
print(f"Cost function for Amundsen: {inv_loss_amundsen}")
# Out:
# Cost function for Amundsen: 2189.225302959573

# %%
def get_phi(h, s):
    g = 9769603575225600.0
    ρ_I = 9.207917118369125e-19
    ρ_W = 1.0282341471330407e-18

    p_W = ρ_W * g * np.maximum(0, h - s)
    p_I = ρ_I * g * h

    # Avoid division by zero with a safe divide
    phi = np.where(p_I > 0, np.maximum((1 - p_W / p_I), 0), 0)
    return phi

def process_csv(filename):
    df = pd.read_csv(filename, index_col=0)
    df = df.sample(frac=1).reset_index(drop=True)
    df['vel_mag'] = np.sqrt(df['x_velocity']**2 + df['y_velocity']**2)
    df['driving_stress'] = df['h'] * 9.8 * df['mag_s']
    df['phi'] = get_phi(df['h'].to_numpy(), df['s'].to_numpy())
    return df

# %%
df_pig = process_csv('regularized_const_01C_C_only_englacial_temp_pig_r005_geo_12.csv')
df_thwaites = process_csv('regularized_const_01C_C_only_englacial_temp_thwaites_r005_geo_12.csv')
df_dotson = process_csv('regularized_const_01C_C_only_englacial_temp_dotson_r005_geo_12.csv')
df_amundsen = process_csv('regularized_const_01C_C_only_englacial_temp_amundsen_r005_geo_12.csv')

# %%
# Prepare training data
coords_pig = df_pig[['x', 'y']].values
coords_thwaites = df_thwaites[['x', 'y']].values
coords_dotson = df_dotson[['x', 'y']].values

# Build KD-Trees for fast distance queries
tree_pig = cKDTree(coords_pig)
tree_thwaites = cKDTree(coords_thwaites)
tree_dotson = cKDTree(coords_dotson)

# Prepare test data
coords_test = df_amundsen[['x', 'y']].values

# %%
from firedrake import dx, max_value, conditional, interpolate, split, sqrt, Function
import numpy as np

def return_percent_diff(inv_obj, select_dataset, tree_pig, tree_thwaites, tree_dotson,
                        threshold=0.1, distance_threshold=2000):
    # Compute norms of velocity fields
    u_inv_norm = inv_obj.get_magnitude(inv_obj.inverse_u)
    u_default_norm = inv_obj.get_magnitude(inv_obj.default_u)
    u_ML_norm = inv_obj.get_magnitude(inv_obj.ML_u)
    phi = inv_obj.compute_phi()

    # Extract mesh coordinates
    x, y = split(interpolate(inv_obj.V.mesh().coordinates, inv_obj.V))
    x_npy = interpolate(x, inv_obj.Q).dat.data_ro[:]
    y_npy = interpolate(y, inv_obj.Q).dat.data_ro[:]
    coords = np.vstack((x_npy, y_npy)).T

    # Query distances to each glacier training dataset
    d_pig, _ = tree_pig.query(coords, k=1)
    d_thwaites, _ = tree_thwaites.query(coords, k=1)
    d_dotson, _ = tree_dotson.query(coords, k=1)

    # Determine closest glacier
    dists = np.vstack([d_pig, d_thwaites, d_dotson]).T
    closest_glacier = np.argmin(dists, axis=1)
    min_dist = np.min(dists, axis=1)

    # Assign labels: 0=PIG, 1=Thwaites, 2=Dotson, 3=Other
    labels = np.where(min_dist > distance_threshold, 3, closest_glacier)

    # Define which glaciers were used for training
    training_glaciers = {
        0: [0, 2, 1],  # PIG, Dotson, Thwaites
        1: [0, 0, 1],  # PIG (twice), Thwaites
        2: [2, 0],     # Dotson, PIG
        3: [2],        # Dotson
        4: [0],        # PIG
        5: [1]         # Thwaites
    }
    training_ids = set(training_glaciers[select_dataset])

    # Create a binary mask: 1 for test region, 0 for training region
    non_training_mask_npy = np.array([1 if label not in training_ids else 0 for label in labels])
    non_training_mask = Function(inv_obj.Q)
    non_training_mask.dat.data[:] = non_training_mask_npy

    # Define region of interest: where phi > threshold and not in training area
    phi_condition = conditional(phi > threshold, 1, 0)
    combined_mask = phi_condition * non_training_mask

    # Calculate percent difference between default and ML solutions
    ml_difference = sqrt((u_inv_norm - u_ML_norm) ** 2)
    default_difference = sqrt((u_inv_norm - u_default_norm) ** 2)
    percent_difference = 100 * (default_difference - ml_difference) / default_difference
    percent_difference_capped = max_value(percent_difference, 0)
    percent_100 = 100 * default_difference / default_difference  # = 100

    # Assemble metric over valid regions
    numerator = firedrake.assemble(percent_difference_capped * combined_mask * dx)
    denominator = firedrake.assemble(percent_100 * combined_mask * dx)

    return numerator / denominator if denominator != 0 else 0

# %%
def compute_area_fraction_above_threshold(inv_obj, select_dataset, tree_pig, tree_thwaites, tree_dotson,
                                          percent_diff_threshold=70.0, threshold=0.1, distance_threshold=2000):
    # Compute velocity magnitudes
    u_inv_norm = inv_obj.get_magnitude(inv_obj.inverse_u)
    u_default_norm = inv_obj.get_magnitude(inv_obj.default_u)
    u_ML_norm = inv_obj.get_magnitude(inv_obj.ML_u)
    phi = inv_obj.compute_phi()

    # Coordinates
    x, y = split(interpolate(inv_obj.V.mesh().coordinates, inv_obj.V))
    x_npy = interpolate(x, inv_obj.Q).dat.data_ro[:]
    y_npy = interpolate(y, inv_obj.Q).dat.data_ro[:]
    coords = np.vstack((x_npy, y_npy)).T

    # Distance queries
    d_pig, _ = tree_pig.query(coords, k=1)
    d_thwaites, _ = tree_thwaites.query(coords, k=1)
    d_dotson, _ = tree_dotson.query(coords, k=1)
    dists = np.vstack([d_pig, d_thwaites, d_dotson]).T
    closest_glacier = np.argmin(dists, axis=1)
    min_dist = np.min(dists, axis=1)

    labels = np.where(min_dist > distance_threshold, 3, closest_glacier)
    training_glaciers = {
        0: [0, 2, 1], 1: [0, 0, 1], 2: [2, 0],
        3: [2], 4: [0], 5: [1]
    }
    training_ids = set(training_glaciers[select_dataset])
    non_training_mask_npy = np.array([1 if label not in training_ids else 0 for label in labels])

    # Masks
    non_training_mask = Function(inv_obj.Q)
    non_training_mask.dat.data[:] = non_training_mask_npy
    phi_condition = conditional(phi > threshold, 1, 0)
    combined_mask = phi_condition * non_training_mask

    # % improvement
    ml_difference = sqrt((u_inv_norm - u_ML_norm) ** 2)
    default_difference = sqrt((u_inv_norm - u_default_norm) ** 2)
    percent_difference = 100 * (default_difference - ml_difference) / default_difference
    percent_difference_capped = max_value(percent_difference, 0)

    # Evaluate coverage
    high_improvement_mask = conditional(percent_difference_capped >= percent_diff_threshold, 1, 0)
    improved_area = firedrake.assemble(high_improvement_mask * combined_mask * dx)
    total_test_area = firedrake.assemble(combined_mask * dx)

    if total_test_area == 0:
        return 0.0  # avoid divide-by-zero

    return improved_area / total_test_area

# %%
import seaborn as sns
from create_percent_diff_summary import FEATURE_SYMBOLS, DATASET_NAMES, TRAINING_MAPPING, CATCHMENT_NAMES

# Initialize a storage dictionary
eval_results = {}

# Precompute and store results for all datasets
for select_dataset in range(6):
    print(f"Processing dataset {select_dataset}...")
    
    eval_results[select_dataset] = {
        "amundsen": eval_models(select_dataset, inv_amundsen)
              }
# Out:
# Processing dataset 0...
# dataset selected: [df_dotson,df_dotson,df_thwaites]
# Processing folder: 3417600685554715613
# 2025-06-26 04:29:47.197602: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# model_3_dotson2_thwaites1_r01_geo_mixed
# ['b', 'mag_b', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 2515623225073686761
# model_2_dotson2_thwaites1_r01_geo_mixed
# ['mag_h', 'mag_s']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 6288890118823552962
# model_10_dotson2_thwaites1_r01_geo_mixed
# ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Processing folder: 4606371850192322534
# model_2_dotson2_thwaites1_r01_geo_mixed
# ['heatflux', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 1339746022886424555
# model_2_dotson2_thwaites1_r01_geo_mixed
# ['s', 'h']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 1984462136783255017
# model_11_dotson2_thwaites1_r01_geo_mixed
# ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: -1951105929351317374
# model_5_dotson2_thwaites1_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s', 'driving_stress']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 1655869088293252897
# model_4_dotson2_thwaites1_r01_geo_mixed
# ['b', 'mag_b', 'heatflux', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 5134346085267747304
# model_3_dotson2_thwaites1_r01_geo_mixed
# ['b', 'mag_b', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Processing folder: 5396535908670673561
# model_4_dotson2_thwaites1_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Processing folder: -6882565723403605683
# model_5_dotson2_thwaites1_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s', 'surface_air_temp']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 5175626151393096290
# model_2_dotson2_thwaites1_r01_geo_mixed
# ['heatflux', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Processing folder: -4601916720263010405
# model_8_dotson2_thwaites1_r01_geo_mixed
# ['b', 'mag_b', 'heatflux', 's', 'h', 'mag_h', 'mag_s', 'surface_air_temp']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# Processing folder: -2874143419160600734
# model_3_dotson2_thwaites1_r01_geo_mixed
# ['b', 'mag_b', 'heatflux']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Processing folder: 3163982775470439979
# model_6_dotson2_thwaites1_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s', 'driving_stress', 'surface_air_temp']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 6067285661158712216
# model_4_dotson2_thwaites1_r01_geo_mixed
# ['b', 'mag_b', 'heatflux', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# Error in simulation
# Defining friction law
# Processing folder: -1250977123492559896
# model_10_dotson2_thwaites1_r01_geo_mixed
# ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing dataset 1...
# dataset selected: [df_pig,df_pig,df_thwaites]
# Processing folder: -4609122930301891904
# model_2_pig2_thwaites1_r01_geo_mixed
# ['heatflux', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: -6631085267247648560
# model_4_pig2_thwaites1_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Error in simulation
# Defining friction law
# Processing folder: -8785817763079055456
# model_3_pig2_thwaites1_r01_geo_mixed
# ['b', 'mag_b', 'heatflux']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Error in simulation
# Defining friction law
# Processing folder: -2338462933391570384
# model_4_pig2_thwaites1_r01_geo_mixed
# ['b', 'mag_b', 'heatflux', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 3530914831355109839
# model_2_pig2_thwaites1_r01_geo_mixed
# ['s', 'h']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# Error in simulation
# Defining friction law
# Processing folder: 3575485704659398926
# model_6_pig2_thwaites1_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s', 'driving_stress', 'surface_air_temp']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Error in simulation
# Defining friction law
# Processing folder: -3636378609531601936
# model_10_pig2_thwaites1_r01_geo_mixed
# ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 3822205729489533866
# model_2_pig2_thwaites1_r01_geo_mixed
# ['heatflux', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 8682276932345511008
# model_3_pig2_thwaites1_r01_geo_mixed
# ['b', 'mag_b', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 7564054531536435645
# model_2_pig2_thwaites1_r01_geo_mixed
# ['mag_h', 'mag_s']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Processing folder: 2319046771559924489
# model_11_pig2_thwaites1_r01_geo_mixed
# ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: -2414931930143235009
# model_3_pig2_thwaites1_r01_geo_mixed
# ['b', 'mag_b', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Processing folder: -5659766501920794929
# model_5_pig2_thwaites1_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s', 'driving_stress']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Error in simulation
# Defining friction law
# Processing folder: 6668736711115154625
# model_8_pig2_thwaites1_r01_geo_mixed
# ['b', 'mag_b', 'heatflux', 's', 'h', 'mag_h', 'mag_s', 'surface_air_temp']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Processing folder: 8499392204521722089
# model_4_pig2_thwaites1_r01_geo_mixed
# ['b', 'mag_b', 'heatflux', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 7046582293374585239
# model_5_pig2_thwaites1_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s', 'surface_air_temp']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Error in simulation
# Defining friction law
# Processing folder: 7888591019679408806
# model_10_pig2_thwaites1_r01_geo_mixed
# ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing dataset 2...
# dataset selected: [df_dotson,df_pig]
# Processing folder: -7528112468957495080
# model_10_dotson_pig_r01_geo_mixed
# ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Processing folder: -8290757040942148978
# model_4_dotson_pig_r01_geo_mixed
# ['b', 'mag_b', 'heatflux', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 6848941764341974965
# model_2_dotson_pig_r01_geo_mixed
# ['mag_h', 'mag_s']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Processing folder: -7439805162454051022
# model_2_dotson_pig_r01_geo_mixed
# ['heatflux', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 6332149343184424627
# model_8_dotson_pig_r01_geo_mixed
# ['b', 'mag_b', 'heatflux', 's', 'h', 'mag_h', 'mag_s', 'surface_air_temp']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 3755580150071907324
# model_3_dotson_pig_r01_geo_mixed
# ['b', 'mag_b', 'heatflux']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Processing folder: -1934445796415771359
# model_5_dotson_pig_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s', 'surface_air_temp']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: -2024432774744499849
# model_6_dotson_pig_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s', 'driving_stress', 'surface_air_temp']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Error in simulation
# Defining friction law
# Processing folder: 1544227153979819221
# model_2_dotson_pig_r01_geo_mixed
# ['s', 'h']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: -3102337722201144552
# model_11_dotson_pig_r01_geo_mixed
# ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 1140785536613630384
# model_3_dotson_pig_r01_geo_mixed
# ['b', 'mag_b', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Error in simulation
# Defining friction law
# Processing folder: 4661282347889674504
# model_4_dotson_pig_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 5297499156161640288
# model_3_dotson_pig_r01_geo_mixed
# ['b', 'mag_b', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Error in simulation
# Defining friction law
# Processing folder: -752360962485616548
# model_4_dotson_pig_r01_geo_mixed
# ['b', 'mag_b', 'heatflux', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Processing folder: 8667383363186529099
# model_10_dotson_pig_r01_geo_mixed
# ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: -8459287368158507132
# model_2_dotson_pig_r01_geo_mixed
# ['heatflux', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Error in simulation
# Defining friction law
# Processing folder: -2054899442105421263
# model_5_dotson_pig_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s', 'driving_stress']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing dataset 3...
# dataset selected: [df_dotson]
# Processing folder: 8171546115081452002
# model_10_dotson_r01_geo_mixed
# ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 224550072714317840
# model_2_dotson_r01_geo_mixed
# ['heatflux', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Processing folder: -6074545629396761247
# model_4_dotson_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# Processing folder: -6739784770853575678
# model_6_dotson_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s', 'driving_stress', 'surface_air_temp']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# Processing folder: -1911502098276543561
# model_10_dotson_r01_geo_mixed
# ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 1684086195150538749
# model_5_dotson_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s', 'surface_air_temp']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Processing folder: 6152629648342203545
# model_11_dotson_r01_geo_mixed
# ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Processing folder: 3200677709741897323
# model_8_dotson_r01_geo_mixed
# ['b', 'mag_b', 'heatflux', 's', 'h', 'mag_h', 'mag_s', 'surface_air_temp']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Processing folder: 3126517756602371852
# model_3_dotson_r01_geo_mixed
# ['b', 'mag_b', 'heatflux']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: -7481047642397578330
# model_4_dotson_r01_geo_mixed
# ['b', 'mag_b', 'heatflux', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 8135244609678663408
# model_2_dotson_r01_geo_mixed
# ['heatflux', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Error in simulation
# Defining friction law
# Processing folder: 7047122258113388958
# model_2_dotson_r01_geo_mixed
# ['mag_h', 'mag_s']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: -3061584795855243830
# model_3_dotson_r01_geo_mixed
# ['b', 'mag_b', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: -3430120633057347389
# model_3_dotson_r01_geo_mixed
# ['b', 'mag_b', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Processing folder: 5248421192049603160
# model_4_dotson_r01_geo_mixed
# ['b', 'mag_b', 'heatflux', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: -1599367748858592155
# model_2_dotson_r01_geo_mixed
# ['s', 'h']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Processing folder: -7704924077959734460
# model_5_dotson_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s', 'driving_stress']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing dataset 4...
# dataset selected: [df_pig]
# Processing folder: 2075614561769015715
# model_4_pig_r01_geo_mixed
# ['b', 'mag_b', 'heatflux', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Error in simulation
# Defining friction law
# Processing folder: 8841118694353468863
# model_2_pig_r01_geo_mixed
# ['mag_h', 'mag_s']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Error in simulation
# Defining friction law
# Processing folder: -5339226243799483527
# model_3_pig_r01_geo_mixed
# ['b', 'mag_b', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Error in simulation
# Defining friction law
# Processing folder: -2740619310642310765
# model_6_pig_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s', 'driving_stress', 'surface_air_temp']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Error in simulation
# Defining friction law
# Processing folder: -1003785993143526674
# model_5_pig_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s', 'driving_stress']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Error in simulation
# Defining friction law
# Processing folder: -4485138934457262928
# model_5_pig_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s', 'surface_air_temp']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: -98631542902948751
# model_4_pig_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Error in simulation
# Defining friction law
# Processing folder: -6128423182858710439
# model_3_pig_r01_geo_mixed
# ['b', 'mag_b', 'heatflux']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Error in simulation
# Defining friction law
# Processing folder: 2527493322429984672
# model_4_pig_r01_geo_mixed
# ['b', 'mag_b', 'heatflux', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Error in simulation
# Defining friction law
# Processing folder: 3201346191993881778
# model_11_pig_r01_geo_mixed
# ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Error in simulation
# Defining friction law
# Processing folder: -6180078295567716747
# model_3_pig_r01_geo_mixed
# ['b', 'mag_b', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Error in simulation
# Defining friction law
# Processing folder: 1366113751283818998
# model_8_pig_r01_geo_mixed
# ['b', 'mag_b', 'heatflux', 's', 'h', 'mag_h', 'mag_s', 'surface_air_temp']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Error in simulation
# Defining friction law
# Processing folder: 5498412892654769408
# model_10_pig_r01_geo_mixed
# ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Error in simulation
# Defining friction law
# Processing folder: 5281767268982107043
# model_10_pig_r01_geo_mixed
# ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Processing folder: -7723818363851199316
# model_2_pig_r01_geo_mixed
# ['heatflux', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Error in simulation
# Defining friction law
# Processing folder: 4068057200681152514
# model_2_pig_r01_geo_mixed
# ['s', 'h']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Error in simulation
# Defining friction law
# Processing folder: 8379897250640128736
# model_2_pig_r01_geo_mixed
# ['heatflux', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Error in simulation
# Defining friction law
# Processing dataset 5...
# dataset selected: [df_thwaites]
# Processing folder: -17701709503968456
# model_2_thwaites_r01_geo_mixed
# ['mag_h', 'mag_s']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 187569401444717716
# model_3_thwaites_r01_geo_mixed
# ['b', 'mag_b', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: -6361290021953980397
# model_4_thwaites_r01_geo_mixed
# ['b', 'mag_b', 'heatflux', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 1245407229515825842
# model_6_thwaites_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s', 'driving_stress', 'surface_air_temp']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 807670798585129242
# model_2_thwaites_r01_geo_mixed
# ['heatflux', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Processing folder: 2028988044653045267
# model_5_thwaites_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s', 'driving_stress']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: -6201189699896637478
# model_11_thwaites_r01_geo_mixed
# ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: -6968457886228324459
# model_10_thwaites_r01_geo_mixed
# ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: -6576748161776868360
# model_10_thwaites_r01_geo_mixed
# ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 4694290331511150013
# model_4_thwaites_r01_geo_mixed
# ['b', 'mag_b', 'heatflux', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# Processing folder: 3141909396794439845
# model_3_thwaites_r01_geo_mixed
# ['b', 'mag_b', 'heatflux']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 5577069988779110031
# model_3_thwaites_r01_geo_mixed
# ['b', 'mag_b', 'mag_anomaly']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 8041281821694802379
# model_4_thwaites_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 7690389490949236527
# model_8_thwaites_r01_geo_mixed
# ['b', 'mag_b', 'heatflux', 's', 'h', 'mag_h', 'mag_s', 'surface_air_temp']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: -7547085032329787218
# model_5_thwaites_r01_geo_mixed
# ['s', 'h', 'mag_h', 'mag_s', 'surface_air_temp']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: 3500596957905382330
# model_2_thwaites_r01_geo_mixed
# ['s', 'h']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Processing folder: -1836950917951320283
# model_2_thwaites_r01_geo_mixed
# ['heatflux', 'gravity_disturbance']
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1119/1119 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Error in simulation
# Defining friction law

# %%
from create_percent_diff_summary import mapping_features

# %%
def reorder_list(lst, index_order):
    # Pair each element in lst with its corresponding index from index_order
    paired = list(zip(index_order, lst))
    
    # Sort the pairs based on the indices from index_order
    paired.sort()
    
    # Extract the sorted elements (second item of the pair) to get the reordered list
    sorted_list = [item[1] for item in paired]
    
    return sorted_list

# %%
all_percent_explained_avg = []

for select_dataset in range(6):
    print(f"Analyzing dataset {select_dataset}...")

    # Retrieve precomputed results for "amundsen"
    temp_objects_amundsen, summary_list_amundsen, columns_list_amundsen, u_optimized_list_amundsen, loss_function_list_amundsen = eval_results[select_dataset]["amundsen"]

    # Reorder using mapping_features if necessary
    index_order = []
    for i in range(len(columns_list_amundsen)):
        for key, value in mapping_features.items():
            if set(value) == set(columns_list_amundsen[i]):
                index_order.append(key)
                break

    temp_objects_amundsen = reorder_list(temp_objects_amundsen, index_order)
    summary_list_amundsen = reorder_list(summary_list_amundsen, index_order)
    u_optimized_list_amundsen = reorder_list(u_optimized_list_amundsen, index_order)
    loss_function_list_amundsen = reorder_list(loss_function_list_amundsen, index_order)
    columns_list_amundsen = reorder_list(columns_list_amundsen, index_order)

    print(columns_list_amundsen)

    # Calculate percent explained for each feature subset
    percent_explained = [return_percent_diff(obj, select_dataset, tree_pig, tree_thwaites, tree_dotson,
                       threshold=0.1, distance_threshold=2000) for obj in temp_objects_amundsen]
    #percent_explained_avg = np.mean(percent_explained, axis=0)  # Not really needed if already 1D
    all_percent_explained_avg.append(percent_explained)
all_percent_explained_avg = np.array(all_percent_explained_avg)
# Out:
# Analyzing dataset 0...
# [['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance', 'mag_anomaly'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 's', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress'], ['s', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s'], ['mag_h', 'mag_s'], ['s', 'h'], ['b', 'mag_b', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux'], ['heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 'mag_anomaly'], ['heatflux', 'mag_anomaly']]
# Analyzing dataset 1...
# [['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance', 'mag_anomaly'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 's', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress'], ['s', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s'], ['mag_h', 'mag_s'], ['s', 'h'], ['b', 'mag_b', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux'], ['heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 'mag_anomaly'], ['heatflux', 'mag_anomaly']]
# Analyzing dataset 2...
# [['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance', 'mag_anomaly'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 's', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress'], ['s', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s'], ['mag_h', 'mag_s'], ['s', 'h'], ['b', 'mag_b', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux'], ['heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 'mag_anomaly'], ['heatflux', 'mag_anomaly']]
# Analyzing dataset 3...
# [['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance', 'mag_anomaly'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 's', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress'], ['s', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s'], ['mag_h', 'mag_s'], ['s', 'h'], ['b', 'mag_b', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux'], ['heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 'mag_anomaly'], ['heatflux', 'mag_anomaly']]
# Analyzing dataset 4...
# [['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance', 'mag_anomaly'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 's', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress'], ['s', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s'], ['mag_h', 'mag_s'], ['s', 'h'], ['b', 'mag_b', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux'], ['heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 'mag_anomaly'], ['heatflux', 'mag_anomaly']]
# Analyzing dataset 5...
# [['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance', 'mag_anomaly'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 's', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress'], ['s', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s'], ['mag_h', 'mag_s'], ['s', 'h'], ['b', 'mag_b', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux'], ['heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 'mag_anomaly'], ['heatflux', 'mag_anomaly']]

# %%
all_area_fractions_above_threshold = []

for select_dataset in range(6):
    print(f"Analyzing dataset {select_dataset}...")

    # Retrieve precomputed results for "amundsen"
    temp_objects_amundsen, summary_list_amundsen, columns_list_amundsen, u_optimized_list_amundsen, loss_function_list_amundsen = eval_results[select_dataset]["amundsen"]

    # Reorder if needed
    index_order = []
    for i in range(len(columns_list_amundsen)):
        for key, value in mapping_features.items():
            if set(value) == set(columns_list_amundsen[i]):
                index_order.append(key)
                break

    temp_objects_amundsen = reorder_list(temp_objects_amundsen, index_order)
    summary_list_amundsen = reorder_list(summary_list_amundsen, index_order)
    u_optimized_list_amundsen = reorder_list(u_optimized_list_amundsen, index_order)
    loss_function_list_amundsen = reorder_list(loss_function_list_amundsen, index_order)
    columns_list_amundsen = reorder_list(columns_list_amundsen, index_order)

    print(columns_list_amundsen)

    # Compute fraction of test area with ≥ 70% improvement
    area_fraction_above_threshold = [
        compute_area_fraction_above_threshold(
            obj, select_dataset, tree_pig, tree_thwaites, tree_dotson,
            percent_diff_threshold=70.0,
            threshold=0.1,
            distance_threshold=2000
        )
        for obj in temp_objects_amundsen
    ]

    all_area_fractions_above_threshold.append(area_fraction_above_threshold)

all_area_fractions_above_threshold = np.array(all_area_fractions_above_threshold)
# Out:
# Analyzing dataset 0...
# [['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance', 'mag_anomaly'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 's', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress'], ['s', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s'], ['mag_h', 'mag_s'], ['s', 'h'], ['b', 'mag_b', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux'], ['heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 'mag_anomaly'], ['heatflux', 'mag_anomaly']]
# Analyzing dataset 1...
# [['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance', 'mag_anomaly'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 's', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress'], ['s', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s'], ['mag_h', 'mag_s'], ['s', 'h'], ['b', 'mag_b', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux'], ['heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 'mag_anomaly'], ['heatflux', 'mag_anomaly']]
# Analyzing dataset 2...
# [['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance', 'mag_anomaly'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 's', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress'], ['s', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s'], ['mag_h', 'mag_s'], ['s', 'h'], ['b', 'mag_b', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux'], ['heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 'mag_anomaly'], ['heatflux', 'mag_anomaly']]
# Analyzing dataset 3...
# [['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance', 'mag_anomaly'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 's', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress'], ['s', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s'], ['mag_h', 'mag_s'], ['s', 'h'], ['b', 'mag_b', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux'], ['heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 'mag_anomaly'], ['heatflux', 'mag_anomaly']]
# Analyzing dataset 4...
# [['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance', 'mag_anomaly'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 's', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress'], ['s', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s'], ['mag_h', 'mag_s'], ['s', 'h'], ['b', 'mag_b', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux'], ['heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 'mag_anomaly'], ['heatflux', 'mag_anomaly']]
# Analyzing dataset 5...
# [['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance', 'mag_anomaly'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'gravity_disturbance'], ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 's', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s', 'driving_stress'], ['s', 'h', 'mag_h', 'mag_s', 'surface_air_temp'], ['s', 'h', 'mag_h', 'mag_s'], ['mag_h', 'mag_s'], ['s', 'h'], ['b', 'mag_b', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'heatflux'], ['heatflux', 'gravity_disturbance'], ['b', 'mag_b', 'mag_anomaly'], ['b', 'mag_b', 'heatflux', 'mag_anomaly'], ['heatflux', 'mag_anomaly']]

# %%
from create_percent_diff_summary import change_feature_label

# %%
# Combine results into a DataFrame for heatmap
# Use the reordered columns_list_amundsen from the last loop
FEATURE_SYMBOLS = {
    "s": r"$s$",
    "b": r"$b$",
    "h": r"$h$",
    "mag_s": r"$\|\nabla s\|$",
    "mag_b": r"$\|\nabla b\|$",
    "mag_h": r"$\|\nabla h\|$",
    "driving_stress": r"$\tau_d$",
    "gravity_disturbance": r"$g_d$",
    "heatflux": r"$Q_b$",
    "surface_air_temp": r"$T_s$",
    "snow_accumulation": r"$A_s$",
    "mag_anomaly": r"$g_b$",
}

def change_feature_label(feature_labels):
    new_order = [r"$s$", r"$b$", r"$h$", r"$\|\nabla h\|$", r"$\|\nabla s\|$", r"$\|\nabla b\|$",    r"$Q_b$",    r"$T_s$"]
    for idx, features in enumerate(feature_labels):
        if set(features) == set(new_order):
            break
    #print(idx)
    feature_labels[idx] = new_order
feature_labels = [[FEATURE_SYMBOLS.get(col, col) for col in sublist] for sublist in columns_list_amundsen]
change_feature_label(feature_labels)
feature_labels_strings = [', '.join(sublist) for sublist in feature_labels]

# Define the ice and geophysical feature types
ice_features = {"s", "h", "mag_s", "mag_h"}
geophysical_features = {"b", "mag_b", "driving_stress", "gravity_disturbance", "heatflux", "surface_air_temp"}

# Function to apply color based on feature type
def get_feature_color(feature):
    if feature in ice_features:
        return "blue"
    elif feature in geophysical_features:
        return "brown"
    else:
        return "black"  # Default color if not classified

# Apply color coding for each feature
colored_labels = [
    [get_feature_color(col) for col in sublist] 
    for sublist in feature_labels
]

# Create DataFrame for heatmap: rows = features, columns = dataset numbers (0–5)
heatmap_data = pd.DataFrame(
    np.array(all_percent_explained_avg).T,  # Transpose to make features rows
    index=feature_labels_strings,
    columns=DATASET_NAMES
)

# Plotting the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(
    heatmap_data,
    annot=True,
    fmt=".2f",
    cmap="YlGn",  # Yellow-Green colormap
    cbar=True,
    vmin=0,
    vmax=1
)
plt.title("Average % Explained for Amundsen Region (Excludes Training Areas)")
plt.xlabel("Training Dataset Combinations")
plt.ylabel("Feature Subsets")
plt.tight_layout()
plt.show()

# %%
# Convert feature names to labels again (reuse last columns_list_amundsen from loop)
feature_labels = [[FEATURE_SYMBOLS.get(col, col) for col in sublist] for sublist in columns_list_amundsen]
change_feature_label(feature_labels)
feature_labels_strings = [', '.join(sublist) for sublist in feature_labels]

# Create DataFrame for heatmap: rows = feature subsets, columns = dataset indices
heatmap_data_area_fraction = pd.DataFrame(
    np.array(all_area_fractions_above_threshold).T,  # Transpose for feature-major layout
    index=feature_labels_strings,
    columns=DATASET_NAMES
)

# Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(
    heatmap_data_area_fraction,
    annot=True,
    fmt=".2f",
    cmap="PuBuGn",  # Green-blue gradient
    cbar=True,
    vmin=0,
    vmax=1
)
plt.title("Fraction of Test Area with ≥70% Improvement (Amundsen Region)")
plt.xlabel("Training Dataset Combinations")
plt.ylabel("Feature Subsets")
plt.tight_layout()
plt.show()

# %%
select_dataset = 1
# Determine the dataset used based on select_dataset
if select_dataset == 0:
    dataset_used = "[df_dotson, df_dotson, df_thwaites]"
elif select_dataset == 1:
    dataset_used = "[df_pig, df_pig, df_thwaites]"
elif select_dataset == 2:
    dataset_used = "[df_dotson, df_pig]"
elif select_dataset == 3:
    dataset_used = "[df_dotson]"
elif select_dataset == 4:
    dataset_used = "[df_pig]"
elif select_dataset == 5:
    dataset_used = "[df_thwaites]"

# Load data for Amundsen only
temp_objects_amundsen, summary_list_amundsen, columns_list_amundsen, u_optimized_list_amundsen, loss_function_list_amundsen = eval_results[select_dataset]["amundsen"]

n_rows = len(temp_objects_amundsen)
fig = plt.figure(figsize=(16, 6 * n_rows))
gs = gridspec.GridSpec(n_rows + 1, 3, width_ratios=[5, 5, 0.2], wspace=0.4, hspace=0.3)

# Title
ax_title = fig.add_subplot(gs[0, :])
title_text = f"Percent Difference Accounted for by ML\nDataset used for training: {dataset_used}"
ax_title.text(0.5, 0.5, title_text, fontsize=16, weight='bold', ha='center', va='center')
ax_title.axis('off')

# Plot each feature subset
for row in range(n_rows):
    # Description
    ax_summary = fig.add_subplot(gs[row + 1, 0])
    summary_text = (
        f"{columns_list_amundsen[row]}\n"
        f"R2 test: {summary_list_amundsen[row]['r2_mean']:.4f}\n"
        f"R2_adjusted test: {summary_list_amundsen[row]['r2_adjusted_mean']:.4f}\n"
        f"MSE test: {summary_list_amundsen[row]['mse_mean']:.4f}\n"
        f"% loss (normalized): {(loss_function_list_amundsen[row] - inv_loss_amundsen) / inv_loss_amundsen:.4f}\n"
        #f"% explained: {return_percent_diff(temp_objects_amundsen[row]):.4f}"
    )
    ax_summary.text(0.1, 0.5, summary_text, fontsize=10, va="center", ha="left")
    ax_summary.axis('off')

    # Plot
    ax_plot = fig.add_subplot(gs[row + 1, 1])
    _, ax_plot = temp_objects_amundsen[row].plot_percent_accounted(vmin=0, vmax=100, axes=ax_plot)
    if row == 0:
        ax_plot.set_title("Amundsen")

    # Colorbar
    cax = fig.add_subplot(gs[row + 1, 2])
    fig.colorbar(ax_plot.collections[0], cax=cax)

plt.show()

# %%
def plot_percent_accounted(inv_obj, vmin=None, vmax=None, axes=None, threshold=0.1, buffer=0.01):
    import firedrake

    percent_difference = inv_obj.calculate_percent_accounted()
    percent_difference_fcn = firedrake.interpolate(percent_difference, inv_obj.Q)

    # Plot on provided axes or create new if None
    if axes is None:
        fig, axes = inv_obj.plot_bounded_antarctica()
    else:
        fig = None

    colors = firedrake.tripcolor(percent_difference_fcn, axes=axes, vmax=vmax, vmin=vmin)

    # Add colorbar only if no external axes were provided
    #if fig is not None:
        #fig.colorbar(colors)

    ϕ = inv_obj.get_phi(inv_obj.h, inv_obj.s)
    Q_temp = firedrake.FunctionSpace(inv_obj.mesh, family="CG", degree=1)
    line = firedrake.interpolate(ϕ, Q_temp)

    # Extract coordinates where phi meets the threshold
    phi_values = line.dat.data[:]
    x = line.function_space().mesh().coordinates.dat.data[:, 0]
    y = line.function_space().mesh().coordinates.dat.data[:, 1]

    # Select coordinates where phi is less than or equal to threshold + buffer
    x_coords = x[(phi_values <= threshold + buffer)]
    y_coords = y[(phi_values <= threshold + buffer)]

    #axes.set_xlabel("UPS x [m]", fontsize=18)  # Adjust font size for x-axis label
    axes.set_ylabel("UPS y [m]", fontsize=18)  # Adjust font size for y-axis label
    axes.tick_params(axis='x', labelsize=18)  # Adjust font size for x-axis ticks
    axes.tick_params(axis='y', labelsize=18)  # Adjust font size for y-axis ticks
    #axes.set_xticklabels([])
    #axes.tick_params(axis='y', labelleft=False)

    # Overlay red dots on the plot
    if len(x_coords) > 0:
        axes.scatter(x_coords, y_coords, color='white', s=5, label='floating ice')
        #axes.legend()

        # Add horizontal colorbar above the image only if figure exists
    if fig is not None:
        # Get axis position to align colorbar width with the plot
        bbox = axes.get_position()
        cbar_height = 0.02  # Thickness of the colorbar
        cbar_pad = 0.01     # Gap between plot and colorbar

        # Create a new axis above the current plot for the colorbar
        cbar_ax = fig.add_axes([
            bbox.x0,
            bbox.y1 + cbar_pad,
            bbox.width,
            cbar_height
        ])

        cbar = fig.colorbar(
            colors,
            cax=cbar_ax,
            orientation='horizontal'
        )
        cbar.ax.xaxis.set_ticks_position('top')
        cbar.ax.xaxis.set_label_position('top')
        cbar.set_label("% explained", fontsize=18)
        cbar.ax.tick_params(labelsize=18)

    #axes.set_title('Percent Difference Accounted for by ML')
    return fig, axes

# %%
def plot_C(inv_obj, vmin=-2, vmax=5, axes=None, threshold=0.1, buffer=0.01):
    import firedrake

    #percent_difference = inv_obj.calculate_percent_accounted()
    #percent_difference_fcn = firedrake.interpolate(percent_difference, inv_obj.Q)

    # Plot on provided axes or create new if None
    if axes is None:
        fig, axes = inv_obj.plot_bounded_antarctica()
    else:
        fig = None

    colors = firedrake.tripcolor(inv_obj.C, axes=axes, vmax=vmax, vmin=vmin)

    # Add colorbar only if no external axes were provided
    #if fig is not None:
    #    fig.colorbar(colors)

    ϕ = inv_obj.get_phi(inv_obj.h, inv_obj.s)
    Q_temp = firedrake.FunctionSpace(inv_obj.mesh, family="CG", degree=1)
    line = firedrake.interpolate(ϕ, Q_temp)

    # Extract coordinates where phi meets the threshold
    phi_values = line.dat.data[:]
    x = line.function_space().mesh().coordinates.dat.data[:, 0]
    y = line.function_space().mesh().coordinates.dat.data[:, 1]

    # Select coordinates where phi is less than or equal to threshold + buffer
    x_coords = x[(phi_values <= threshold + buffer)]
    y_coords = y[(phi_values <= threshold + buffer)]

    #axes.set_xlabel("UPS x [m]", fontsize=18)  # Adjust font size for x-axis label
    #axes.set_ylabel("UPS y [m]", fontsize=18)  # Adjust font size for y-axis label
    axes.tick_params(axis='x', labelsize=18)  # Adjust font size for x-axis ticks
    #axes.tick_params(axis='y', labelsize=18)  # Adjust font size for y-axis ticks
    axes.tick_params(axis='y', labelleft=False)
    #axes.set_xticklabels([])
    axes.set_yticklabels([])

    # Overlay red dots on the plot
    if len(x_coords) > 0:
        axes.scatter(x_coords, y_coords, color='white', s=5, label='floating ice')
        #axes.legend()

    # # Add horizontal colorbar above the image only if figure exists
    if fig is not None:
        # Match colorbar width to the axis
        bbox = axes.get_position()
        cbar_height = 0.02  # Controls colorbar thickness
        cbar_pad = 0.01     # Distance above plot

        cbar_ax = fig.add_axes([
            bbox.x0,
            bbox.y1 + cbar_pad,
            bbox.width,
            cbar_height
        ])

        cbar = fig.colorbar(
            colors,
            cax=cbar_ax,
            orientation='horizontal'
        )
        cbar.ax.xaxis.set_ticks_position('top')
        cbar.ax.xaxis.set_label_position('top')
        #cbar.set_label("Basal friction coefficient $C$ [m yr$^{-1}$/Pa]", fontsize=18)
        cbar.set_label("C", fontsize=18)
        cbar.ax.tick_params(labelsize=18)

    #axes.set_title('Percent Difference Accounted for by ML')
    return fig, axes

# %%
def plot_u_error_no_sigma(inv_obj, u, vmin=None, vmax=None, threshold=0.1, buffer=0.01, axes=None, title=False):
    """Plot error in u compared to u_initial."""
    # Plot on provided axes or create new if None
    if axes is None:
        fig, axes = inv_obj.plot_bounded_antarctica()
    else:
        fig = None

    #axes.set_xlabel("UPS x [m]", fontsize=18)  # Adjust font size for x-axis label
    #axes.set_ylabel("UPS y [m]", fontsize=18)  # Adjust font size for y-axis label
    axes.tick_params(axis='x', labelsize=18)  # Adjust font size for x-axis ticks
    axes.tick_params(axis='y', labelsize=18)  # Adjust font size for y-axis ticks
    #axes.set_xticklabels([])
    axes.set_yticklabels([])

    δu = firedrake.interpolate(firedrake.sqrt((u - inv_obj.u_initial)**2), inv_obj.Q)
    colors = firedrake.tripcolor(
        δu, vmin=vmin, vmax=vmax, cmap="Reds", axes=axes
    )

    φ = inv_obj.get_phi(inv_obj.h, inv_obj.s)
    Q_temp = firedrake.FunctionSpace(inv_obj.mesh, family="CG", degree=1)
    line = firedrake.interpolate(φ, Q_temp)

    # Extract coordinates where phi meets the threshold
    phi_values = line.dat.data[:]
    x = line.function_space().mesh().coordinates.dat.data[:, 0]
    y = line.function_space().mesh().coordinates.dat.data[:, 1]

    x_coords = x[(phi_values <= threshold + buffer)]
    y_coords = y[(phi_values <= threshold + buffer)]

    # Overlay red dots on the plot
    if len(x_coords) > 0:
        axes.scatter(x_coords, y_coords, color='white', s=2, label='floating ice')
        #axes.legend()

    # # Add colorbar only if no external axes were provided
    if fig is not None:
        # Create a new axes above the image for the colorbar
        bbox = axes.get_position()
        cbar_height = 0.02  # Adjust height of the colorbar
        cbar_pad = 0.01     # Adjust padding between image and colorbar

        cbar_ax = fig.add_axes([
            bbox.x0,
            bbox.y1 + cbar_pad,  # Place above the image
            bbox.width,
            cbar_height
        ])

        cbar = fig.colorbar(
            colors,
            cax=cbar_ax,
            orientation='horizontal'
        )
        cbar.set_label("m/yr", fontsize=18)
        cbar.ax.tick_params(labelsize=18)
        # Move ticks and label to the top
        cbar.ax.xaxis.set_ticks_position('top')
        cbar.ax.xaxis.set_label_position('top')

    if title:
        axes.set_title("Error in U")
    
    return fig, axes

# %%
def plot_single_feature_amundsen(select_dataset, feature_index, eval_results, inv_loss_amundsen):
    # Map dataset number to training datasets used
    dataset_map = {
        0: "[df_dotson, df_dotson, df_thwaites]",
        1: "[df_pig, df_pig, df_thwaites]",
        2: "[df_dotson, df_pig]",
        3: "[df_dotson]",
        4: "[df_pig]",
        5: "[df_thwaites]"
    }
    dataset_used = dataset_map[select_dataset]

    # Unpack results
    temp_objects, summary_list, columns_list, _, loss_function_list = eval_results[select_dataset]["amundsen"]

    # Safety check
    if feature_index < 0 or feature_index >= len(temp_objects):
        raise ValueError(f"Invalid feature index {feature_index}. Must be between 0 and {len(temp_objects)-1}.")

    inv_obj = temp_objects[feature_index]

    # Combine feature names with underscores
    features_str = '_'.join(columns_list[feature_index])





    # Print everything
    print(f"\n🧠 Dataset used for training: {dataset_used}")
    print(f"📊 Features used: {columns_list[feature_index]}")
    print(f"📁 Feature-Dataset Key: {features_str}")
    print(f"📈 R2 test: {summary_list[feature_index]['r2_mean']:.4f}")
    print(f"📈 R2 adjusted test: {summary_list[feature_index]['r2_adjusted_mean']:.4f}")
    print(f"📉 MSE test: {summary_list[feature_index]['mse_mean']:.4f}")
    print(f"📉 % loss (normalized): "
        f"{(loss_function_list[feature_index] - inv_loss_amundsen) / inv_loss_amundsen:.4f}\n")

    # Create Antarctica background map
    #fig, ax = inv_obj.plot_bounded_antarctica()

    # Overlay percent explained
    #_, ax = 
    plot_percent_accounted(inv_obj,vmin=0, vmax=100)#, axes=ax)
    plot_C(inv_obj, vmin=-2, vmax=5)
    plot_u_error_no_sigma(inv_obj, inv_obj.ML_u, vmin=None, vmax=100)
    inv_obj.plot_u_error_percentage(inv_obj.ML_u)
    # Title and layout
    #ax.set_title("Percent Difference Accounted (Excludes Training Regions)", fontsize=12)
    #fig.tight_layout()
    plt.show()

# %%
#4: 7, 11, 12, 13, 14
#1: 2, 13, 6, 16, 0
plot_single_feature_amundsen(
    select_dataset=4,
    feature_index=14,
    eval_results=eval_results,
    inv_loss_amundsen=inv_loss_amundsen
)
# Out:
# 🧠 Dataset used for training: [df_pig]
# 📊 Features used: ['heatflux', 'mag_anomaly']
# 📁 Feature-Dataset Key: heatflux_mag_anomaly
# 📈 R2 test: 0.6142
# 📈 R2 adjusted test: 0.6142
# 📉 MSE test: 0.3981
# 📉 % loss (normalized): 71876.8154
