# %%
from mlp_ensemble import get_model_summary, process_csv
# Out:
# 2025-12-09 10:35:40.602303: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-09 10:35:40.613724: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765276540.627707      98 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765276540.632363      98 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
column_list = [
    ###['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'boug_anomaly', 'heatflux', 'snow_accumulation', 'surface_air_temp','gravity_disturbance'], ## #all columns
    ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp','gravity_disturbance', 'mag_anomaly'],
    ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp','gravity_disturbance'], #
    ['s',  'h', 'mag_h', 'mag_s', 'driving_stress', 'surface_air_temp'], # # dynamic columns 
    ['s',  'h', 'mag_h', 'mag_s', 'driving_stress'],  
    ['s',  'h', 'mag_h', 'mag_s', 'surface_air_temp'], 
    ['s',  'h', 'mag_h', 'mag_s'], 
    ['mag_h', 'mag_s'], #
    ['s',  'h'], #
    ['b', 'mag_b','gravity_disturbance'], #
    ['b', 'mag_b', 'heatflux', 'gravity_disturbance'], 
    ['b', 'mag_b','heatflux'], 
    ['heatflux', 'gravity_disturbance'], 
    ['b', 'mag_b','heatflux', 's',  'h', 'mag_h', 'mag_s', 'surface_air_temp'], 
    ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp','mag_anomaly'],
    ['b', 'mag_b','mag_anomaly'],
    ['b', 'mag_b', 'heatflux', 'mag_anomaly'],
    ['heatflux', 'mag_anomaly'],
    
]

# %%
df_summary = get_model_summary(base_folder = 'mlp_ensemble/mlp_ensemble_englacial_0')
# Out:
# Processing folder: -1250977123492559896
# /srv/conda/envs/notebook/lib/python3.12/site-packages/sklearn/base.py:442: InconsistentVersionWarning: Trying to unpickle estimator RobustScaler from version 1.5.2 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 2025-12-09 10:36:03.805637: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Processing folder: 1339746022886424555
# /srv/conda/envs/notebook/lib/python3.12/site-packages/sklearn/base.py:442: InconsistentVersionWarning: Trying to unpickle estimator RobustScaler from version 1.5.2 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# ...

# %%
df_summary
# Out:
#            folder_name                                      input_columns  \
# 0  7869387175083977816  [s, b, h, mag_h, mag_s, mag_b, driving_stress,...
# 1 -1827688566475450412  [s, b, h, mag_h, mag_s, mag_b, driving_stress,...
# 2  8519678655328240356  [s, b, h, mag_h, mag_s, mag_b, driving_stress,...
# 3  7768102228050176001  [b, mag_b, heatflux, mag_anomaly, bed_class_0,...
# 4 -2554643417289674753  [s, b, h, mag_h, mag_s, mag_b, driving_stress,...
# 5  2080653115115859318  [s, b, h, mag_h, mag_s, mag_b, driving_stress,...
# 6  5965017052195726040  [s, b, h, mag_h, mag_s, mag_b, driving_stress,...
# 7  -327631788991699755  [s, b, h, mag_h, mag_b, heatflux, gravity_dist...
#
#     r2_mean    r2_std  r2_median  r2_adjusted_mean  r2_adjusted_std  \
# 0  0.978127  0.049262   0.996038          0.978125         0.049267
# 1  0.952155  0.058320   0.993011          0.952150         0.058326
# 2  0.978539  0.028697   0.995167          0.978537         0.028700
# ...

# %%
duplicates = df_summary[df_summary['input_columns'].duplicated(keep=False)]

# Display duplicates
print(duplicates)
# Out:
#            folder_name                                      input_columns  \
# 0  7869387175083977816  [s, b, h, mag_h, mag_s, mag_b, driving_stress,...
# 1 -1827688566475450412  [s, b, h, mag_h, mag_s, mag_b, driving_stress,...
# 2  8519678655328240356  [s, b, h, mag_h, mag_s, mag_b, driving_stress,...
# 5  2080653115115859318  [s, b, h, mag_h, mag_s, mag_b, driving_stress,...
# 6  5965017052195726040  [s, b, h, mag_h, mag_s, mag_b, driving_stress,...
#
#     r2_mean    r2_std  r2_median  r2_adjusted_mean  r2_adjusted_std  \
# 0  0.978127  0.049262   0.996038          0.978125         0.049267
# 1  0.952155  0.058320   0.993011          0.952150         0.058326
# 2  0.978539  0.028697   0.995167          0.978537         0.028700
# 5  0.978361  0.028115   0.991397          0.978359         0.028118
# 6  0.994892  0.001100   0.994536          0.994891         0.001100
#
#    r2_adjusted_median  mse_mean   mse_std  mse_median  number_of_models
# ...

# %%
df_summary['input_columns']
# Out:
# 0    [s, b, h, mag_h, mag_s, mag_b, driving_stress,...
# 1    [s, b, h, mag_h, mag_s, mag_b, driving_stress,...
# 2    [s, b, h, mag_h, mag_s, mag_b, driving_stress,...
# 3    [b, mag_b, heatflux, mag_anomaly, bed_class_0,...
# 4    [s, b, h, mag_h, mag_s, mag_b, driving_stress,...
# 5    [s, b, h, mag_h, mag_s, mag_b, driving_stress,...
# 6    [s, b, h, mag_h, mag_s, mag_b, driving_stress,...
# 7    [s, b, h, mag_h, mag_b, heatflux, gravity_dist...
# Name: input_columns, dtype: object

# %%
import pandas
# Set max_colwidth to None to display the full content of the cells
pandas.set_option('display.max_colwidth', None)

# Display the DataFrame again
print(df_summary['input_columns'].to_string())
# Out:
# 0    [s, b, h, mag_h, mag_s, mag_b, driving_stress, heatflux, surface_air_temp, gravity_disturbance, mag_anomaly, bed_class_0, bed_class_1, bed_class_2, bed_class_3]
# 1    [s, b, h, mag_h, mag_s, mag_b, driving_stress, heatflux, surface_air_temp, gravity_disturbance, mag_anomaly, bed_class_0, bed_class_1, bed_class_2, bed_class_3]
# 2    [s, b, h, mag_h, mag_s, mag_b, driving_stress, heatflux, surface_air_temp, gravity_disturbance, mag_anomaly, bed_class_0, bed_class_1, bed_class_2, bed_class_3]
# 3                                                                               [b, mag_b, heatflux, mag_anomaly, bed_class_0, bed_class_1, bed_class_2, bed_class_3]
# 4                         [s, b, h, mag_h, mag_s, mag_b, driving_stress, heatflux, surface_air_temp, mag_anomaly, bed_class_0, bed_class_1, bed_class_2, bed_class_3]
# ...

# %%
# Convert lists to sets of tuples for comparison
column_list_set = set(map(tuple, column_list))
df_summary_set = set(map(tuple, df_summary['input_columns']))

# Find missing lists
missing_lists = column_list_set - df_summary_set

# Convert back to lists if needed
missing_lists = [list(lst) for lst in missing_lists]

print("Missing lists:", missing_lists)
# Out:
# Missing lists: []

# %%
# df_pig = process_csv('regularized_const_01C_C_only_englacial_temp_pig_r005_geo_12.csv')
# df_thwaites = process_csv('regularized_const_01C_C_only_englacial_temp_thwaites_r005_geo_12.csv')
# df_dotson = process_csv('regularized_const_01C_C_only_englacial_temp_dotson_r005_geo_12.csv')

# %%
# df_thwaites['C'].min(), df_thwaites['C'].max(), df_thwaites['theta'].min(), df_thwaites['theta'].max()

# %%
# df_dotson['C'].min(), df_dotson['C'].max(), df_dotson['theta'].min(), df_dotson['theta'].max()

# %%
# df_pig['C'].min(), df_pig['C'].max(), df_pig['theta'].min(), df_pig['theta'].max()
