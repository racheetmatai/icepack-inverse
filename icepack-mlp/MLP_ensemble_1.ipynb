# %%
from mlp_ensemble import loop_train_ensemble_mlp_model, train_ensemble_mlp_model, load_ensemble_mlp_model
# Out:
# 2025-11-02 22:06:35.369508: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-02 22:06:35.394786: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-02 22:06:35.401715: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-02 22:06:35.417254: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# import os
# os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
# import pickle
# import os
# base_folder = os.path.join('mlp_ensemble', '4628765226947308793', 'model_4_dotson2_thwaites1_r1_geo_mixed_C_0.pkl')
# with open(base_folder, "rb") as f:
#     model_bundle = pickle.load(f)

# %%
# model_bundle['input_columns']

# %%
column_list = [
    ###['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'mag_anomaly', 'heatflux', 'snow_accumulation', 'surface_air_temp','gravity_disturbance'], ## #all columns
    ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp','gravity_disturbance', 'mag_anomaly'],
    ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp','gravity_disturbance'], #
    ['s',  'h', 'mag_h', 'mag_s', 'driving_stress', 'surface_air_temp'], # # dynamic columns 
    ['s',  'h', 'mag_h', 'mag_s', 'driving_stress'],  
    ['s',  'h', 'mag_h', 'mag_s', 'surface_air_temp'], 
    ['s',  'h', 'mag_h', 'mag_s'], 
    ['mag_h', 'mag_s'], #
    ['s',  'h'], #
    ['b', 'mag_b','gravity_disturbance'], #
    ['b', 'mag_b', 'heatflux', 'gravity_disturbance'], 
    ['b', 'mag_b','heatflux'], 
    ['heatflux', 'gravity_disturbance'], 
    ['b', 'mag_b','heatflux', 's',  'h', 'mag_h', 'mag_s', 'surface_air_temp'], 
    ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp','mag_anomaly'],
    ['b', 'mag_b','mag_anomaly'],
    ['b', 'mag_b', 'heatflux', 'mag_anomaly'],
    ['heatflux', 'mag_anomaly'],
    
]
number_of_models =10
epochs = 700

# %%
model_list, input_scaler_list, output_scaler_list, history_list, r2_stats_list, r2_adjusted_stats_list, mse_stats_list, df_summary = loop_train_ensemble_mlp_model(column_list , epochs = epochs, variable = 'C', number_of_models = number_of_models, bad_r2_score = -500, start_number = 0, variable_type = 'mixed', select_dataset = 0, base_folder_name = 'mlp_ensemble_englacial', use_boug_anomaly_filter='True')
#model_list, input_scaler, output_scaler, history_list = train_ensemble_mlp_model(epochs = 500, variable = 'C', number_of_models = number_of_models, columns = static_columns, bad_r2_score = 0.2, start_number = 0, variable_type = 'static')
# Out:
# dataset selected: [df_dotson (weight=2), df_thwaites (weight=1)]
# /srv/conda/envs/notebook/lib/python3.12/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-08-20 23:35:50.878800: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13775 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Epoch 1/700
# 2025-08-20 23:36:00.564214: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-08-20 23:36:01.355139: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 91001
#   41/6064 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - loss: 1.4325
# 2025-08-20 23:36:03.185061: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_3', 160 bytes spill stores, 160 bytes spill loads
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3041
# 2025-08-20 23:36:29.089391: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_3', 160 bytes spill stores, 160 bytes spill loads
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 39s 5ms/step - loss: 0.3041 - val_loss: 0.1234 - learning_rate: 0.0010
# Epoch 2/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - loss: 0.1566 - val_loss: 0.3543 - learning_rate: 0.0010
# Epoch 3/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - loss: 0.1242 - val_loss: 0.1127 - learning_rate: 0.0010
# Epoch 4/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step - loss: 0.1020 - val_loss: 0.0901 - learning_rate: 0.0010
# Epoch 5/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 0.0897 - val_loss: 0.0569 - learning_rate: 0.0010
# Epoch 6/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 0.0792 - val_loss: 0.1147 - learning_rate: 0.0010
# Epoch 7/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step - loss: 0.0774 - val_loss: 0.0548 - learning_rate: 0.0010
# Epoch 8/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step - loss: 0.0702 - val_loss: 0.0610 - learning_rate: 0.0010
# Epoch 9/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step - loss: 0.0627 - val_loss: 0.0481 - learning_rate: 0.0010
# Epoch 10/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step - loss: 0.0550 - val_loss: 0.0808 - learning_rate: 0.0010
# Epoch 11/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step - loss: 0.0600 - val_loss: 0.0577 - learning_rate: 0.0010
# Epoch 12/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step - loss: 0.0478 - val_loss: 0.0476 - learning_rate: 0.0010
# Epoch 13/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step - loss: 0.0474 - val_loss: 0.0479 - learning_rate: 0.0010
# Epoch 14/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 0.0457 - val_loss: 0.0425 - learning_rate: 0.0010
# Epoch 15/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 0.0377 - val_loss: 0.0387 - learning_rate: 0.0010
# Epoch 16/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step - loss: 0.0396 - val_loss: 0.0360 - learning_rate: 0.0010
# Epoch 17/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 0.0414 - val_loss: 0.0217 - learning_rate: 0.0010
# Epoch 18/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step - loss: 0.0372 - val_loss: 0.0523 - learning_rate: 0.0010
# Epoch 19/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 0.0336 - val_loss: 0.0277 - learning_rate: 0.0010
# Epoch 20/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 0.0320 - val_loss: 0.0438 - learning_rate: 0.0010
# Epoch 21/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 0.0301 - val_loss: 0.0270 - learning_rate: 0.0010
# Epoch 22/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 0.0330 - val_loss: 0.0191 - learning_rate: 0.0010
# Epoch 23/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step - loss: 0.0279 - val_loss: 0.0378 - learning_rate: 0.0010
# Epoch 24/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 0.0341 - val_loss: 0.0348 - learning_rate: 0.0010
# Epoch 25/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 28s 5ms/step - loss: 0.0296 - val_loss: 0.0276 - learning_rate: 0.0010
# Epoch 26/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 28s 5ms/step - loss: 0.0276 - val_loss: 0.0301 - learning_rate: 0.0010
# Epoch 27/700
# 6064/6064 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 0.0259 - val_loss: 0.0316 - learning_rate: 0.0010
# Epoch 28/700
# 1922/6064 ━━━━━━━━━━━━━━━━━━━━ 17s 4ms/step - loss: 0.0244

# %%
df_summary

# %%
#model_list, input_scaler, output_scaler, input_columns, variable = load_ensemble_mlp_model(input_columns, number_of_models = len(model_list), variable = 'C')
