# %%
from mlp_ensemble import loop_train_ensemble_mlp_model, train_ensemble_mlp_model, load_ensemble_mlp_model
# Out:
# 2025-08-20 23:35:48.120078: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-08-20 23:35:48.141706: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-08-20 23:35:48.148717: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-08-20 23:35:48.163927: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# import os
# os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
# import pickle
# import os
# base_folder = os.path.join('mlp_ensemble', '4628765226947308793', 'model_4_dotson2_thwaites1_r1_geo_mixed_C_0.pkl')
# with open(base_folder, "rb") as f:
#     model_bundle = pickle.load(f)

# %%
# model_bundle['input_columns']

# %%
column_list = [
    ###['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'mag_anomaly', 'heatflux', 'snow_accumulation', 'surface_air_temp','gravity_disturbance'], ## #all columns
    ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp','gravity_disturbance', 'mag_anomaly'],
    ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp','gravity_disturbance'], #
    ['s',  'h', 'mag_h', 'mag_s', 'driving_stress', 'surface_air_temp'], # # dynamic columns 
    ['s',  'h', 'mag_h', 'mag_s', 'driving_stress'],  
    ['s',  'h', 'mag_h', 'mag_s', 'surface_air_temp'], 
    ['s',  'h', 'mag_h', 'mag_s'], 
    ['mag_h', 'mag_s'], #
    ['s',  'h'], #
    ['b', 'mag_b','gravity_disturbance'], #
    ['b', 'mag_b', 'heatflux', 'gravity_disturbance'], 
    ['b', 'mag_b','heatflux'], 
    ['heatflux', 'gravity_disturbance'], 
    ['b', 'mag_b','heatflux', 's',  'h', 'mag_h', 'mag_s', 'surface_air_temp'], 
    ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'surface_air_temp','mag_anomaly'],
    ['b', 'mag_b','mag_anomaly'],
    ['b', 'mag_b', 'heatflux', 'mag_anomaly'],
    ['heatflux', 'mag_anomaly'],
    
]
number_of_models =10
epochs = 700

# %%
model_list, input_scaler_list, output_scaler_list, history_list, r2_stats_list, r2_adjusted_stats_list, mse_stats_list, df_summary = loop_train_ensemble_mlp_model(column_list, epochs = epochs, variable = 'C', number_of_models = number_of_models, bad_r2_score = -500, bad_mse_score=100, start_number = 0, variable_type = 'mixed', select_dataset = 2, base_folder_name = 'mlp_ensemble_englacial', use_boug_anomaly_filter = 'True')
#model_list, input_scaler, output_scaler, history_list = train_ensemble_mlp_model(epochs = 500, variable = 'C', number_of_models = number_of_models, columns = static_columns, bad_r2_score = 0.2, start_number = 0, variable_type = 'static')
# Out:
# dataset selected: [df_dotson (weight=1), df_pig (weight=1)]
# /srv/conda/envs/notebook/lib/python3.12/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-08-20 23:36:04.175158: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13775 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Epoch 1/700
# 2025-08-20 23:36:12.613708: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-08-20 23:36:13.313281: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 91001
#   43/2053 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 1.4412
# 2025-08-20 23:36:14.959453: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_3', 160 bytes spill stores, 160 bytes spill loads
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5425
# 2025-08-20 23:36:24.134937: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_3', 160 bytes spill stores, 160 bytes spill loads
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - loss: 0.5424 - val_loss: 0.2857 - learning_rate: 0.0010
# Epoch 2/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.3322 - val_loss: 0.3235 - learning_rate: 0.0010
# Epoch 3/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.2751 - val_loss: 0.1992 - learning_rate: 0.0010
# Epoch 4/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.2268 - val_loss: 0.2756 - learning_rate: 0.0010
# Epoch 5/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.2005 - val_loss: 0.3319 - learning_rate: 0.0010
# Epoch 6/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.2301 - val_loss: 0.1408 - learning_rate: 0.0010
# Epoch 7/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.1551 - val_loss: 0.1865 - learning_rate: 0.0010
# Epoch 8/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.1554 - val_loss: 0.2185 - learning_rate: 0.0010
# Epoch 9/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.1383 - val_loss: 0.2017 - learning_rate: 0.0010
# Epoch 10/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.1162 - val_loss: 0.1631 - learning_rate: 0.0010
# Epoch 11/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.1147 - val_loss: 0.1859 - learning_rate: 0.0010
# Epoch 12/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.1028 - val_loss: 0.2597 - learning_rate: 0.0010
# Epoch 13/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.1315 - val_loss: 0.0928 - learning_rate: 0.0010
# Epoch 14/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.1292 - val_loss: 0.1642 - learning_rate: 0.0010
# Epoch 15/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0985 - val_loss: 0.1825 - learning_rate: 0.0010
# Epoch 16/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.1056 - val_loss: 0.2478 - learning_rate: 0.0010
# Epoch 17/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0957 - val_loss: 0.1480 - learning_rate: 0.0010
# Epoch 18/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0863 - val_loss: 0.1292 - learning_rate: 0.0010
# Epoch 19/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0744 - val_loss: 0.4955 - learning_rate: 0.0010
# Epoch 20/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0835 - val_loss: 0.1751 - learning_rate: 0.0010
# Epoch 21/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0833 - val_loss: 0.1242 - learning_rate: 0.0010
# Epoch 22/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0701 - val_loss: 0.1079 - learning_rate: 0.0010
# Epoch 23/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0680 - val_loss: 0.1497 - learning_rate: 0.0010
# Epoch 24/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0737 - val_loss: 0.0830 - learning_rate: 0.0010
# Epoch 25/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0610 - val_loss: 0.0806 - learning_rate: 0.0010
# Epoch 26/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0589 - val_loss: 0.1113 - learning_rate: 0.0010
# Epoch 27/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0593 - val_loss: 0.0666 - learning_rate: 0.0010
# Epoch 28/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0553 - val_loss: 0.0606 - learning_rate: 0.0010
# Epoch 29/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0556 - val_loss: 0.2048 - learning_rate: 0.0010
# Epoch 30/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0537 - val_loss: 0.0737 - learning_rate: 0.0010
# Epoch 31/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0543 - val_loss: 0.0446 - learning_rate: 0.0010
# Epoch 32/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0491 - val_loss: 0.0854 - learning_rate: 0.0010
# Epoch 33/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0544 - val_loss: 0.0529 - learning_rate: 0.0010
# Epoch 34/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0636 - val_loss: 0.0386 - learning_rate: 0.0010
# Epoch 35/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0480 - val_loss: 0.0662 - learning_rate: 0.0010
# Epoch 36/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0429 - val_loss: 0.0708 - learning_rate: 0.0010
# Epoch 37/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0464 - val_loss: 0.0316 - learning_rate: 0.0010
# Epoch 38/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0504 - val_loss: 0.0349 - learning_rate: 0.0010
# Epoch 39/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0418 - val_loss: 0.0474 - learning_rate: 0.0010
# Epoch 40/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0532 - val_loss: 0.0612 - learning_rate: 0.0010
# Epoch 41/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0564 - val_loss: 0.0433 - learning_rate: 0.0010
# Epoch 42/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0416 - val_loss: 0.1008 - learning_rate: 0.0010
# Epoch 43/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0418 - val_loss: 0.0351 - learning_rate: 0.0010
# Epoch 44/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0426 - val_loss: 0.0458 - learning_rate: 0.0010
# Epoch 45/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0448 - val_loss: 0.0966 - learning_rate: 0.0010
# Epoch 46/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0338 - val_loss: 0.0695 - learning_rate: 0.0010
# Epoch 47/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0457 - val_loss: 0.0347 - learning_rate: 0.0010
# Epoch 48/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0315 - val_loss: 0.0380 - learning_rate: 0.0010
# Epoch 49/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0624 - val_loss: 0.0316 - learning_rate: 0.0010
# Epoch 50/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0329 - val_loss: 0.0305 - learning_rate: 0.0010
# Epoch 51/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0361 - val_loss: 0.0476 - learning_rate: 0.0010
# Epoch 52/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0403 - val_loss: 0.0364 - learning_rate: 0.0010
# Epoch 53/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0331 - val_loss: 0.1869 - learning_rate: 0.0010
# Epoch 54/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0520 - val_loss: 0.1098 - learning_rate: 0.0010
# Epoch 55/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0362 - val_loss: 0.0742 - learning_rate: 0.0010
# Epoch 56/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0382 - val_loss: 0.1484 - learning_rate: 0.0010
# Epoch 57/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0360 - val_loss: 0.0376 - learning_rate: 0.0010
# Epoch 58/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0316 - val_loss: 0.0328 - learning_rate: 0.0010
# Epoch 59/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0384 - val_loss: 0.1183 - learning_rate: 0.0010
# Epoch 60/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0394 - val_loss: 0.0403 - learning_rate: 0.0010
# Epoch 61/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0289 - val_loss: 0.0422 - learning_rate: 0.0010
# Epoch 62/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0289 - val_loss: 0.0573 - learning_rate: 0.0010
# Epoch 63/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0303 - val_loss: 0.0538 - learning_rate: 0.0010
# Epoch 64/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0287 - val_loss: 0.0463 - learning_rate: 0.0010
# Epoch 65/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0321 - val_loss: 0.0851 - learning_rate: 0.0010
# Epoch 66/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0310 - val_loss: 0.0258 - learning_rate: 0.0010
# Epoch 67/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0453 - val_loss: 0.0416 - learning_rate: 0.0010
# Epoch 68/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0395 - val_loss: 0.0375 - learning_rate: 0.0010
# Epoch 69/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0278 - val_loss: 0.0640 - learning_rate: 0.0010
# Epoch 70/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0295 - val_loss: 0.0782 - learning_rate: 0.0010
# Epoch 71/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0276 - val_loss: 0.0483 - learning_rate: 0.0010
# Epoch 72/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0271 - val_loss: 0.0767 - learning_rate: 0.0010
# Epoch 73/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0289 - val_loss: 0.0326 - learning_rate: 0.0010
# Epoch 74/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0253 - val_loss: 0.0602 - learning_rate: 0.0010
# Epoch 75/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0239 - val_loss: 0.0959 - learning_rate: 0.0010
# Epoch 76/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0245 - val_loss: 0.0926 - learning_rate: 0.0010
# Epoch 77/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0273 - val_loss: 0.0602 - learning_rate: 0.0010
# Epoch 78/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0278 - val_loss: 0.0228 - learning_rate: 0.0010
# Epoch 79/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0305 - val_loss: 0.0476 - learning_rate: 0.0010
# Epoch 80/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0264 - val_loss: 0.0629 - learning_rate: 0.0010
# Epoch 81/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0279 - val_loss: 0.0533 - learning_rate: 0.0010
# Epoch 82/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0303 - val_loss: 0.0370 - learning_rate: 0.0010
# Epoch 83/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0212 - val_loss: 0.0538 - learning_rate: 0.0010
# Epoch 84/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0256 - val_loss: 0.0374 - learning_rate: 0.0010
# Epoch 85/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0308 - val_loss: 0.0594 - learning_rate: 0.0010
# Epoch 86/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0218 - val_loss: 0.0285 - learning_rate: 0.0010
# Epoch 87/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0254 - val_loss: 0.0300 - learning_rate: 0.0010
# Epoch 88/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0193 - val_loss: 0.0368 - learning_rate: 0.0010
# Epoch 89/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0215 - val_loss: 0.0405 - learning_rate: 0.0010
# Epoch 90/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0247 - val_loss: 0.0277 - learning_rate: 0.0010
# Epoch 91/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0207 - val_loss: 0.0205 - learning_rate: 0.0010
# Epoch 92/700
# 2053/2053 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0339 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 93/700
#  195/2053 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0184

# %%
df_summary

# %%
#model_list, input_scaler, output_scaler, input_columns, variable = load_ensemble_mlp_model(input_columns, number_of_models = len(model_list), variable = 'C')
