# %%
import matplotlib.pyplot as plt
from src.invert_c_theta import Invert
import pandas as pd
import firedrake
# Out:
# 2024-11-25 17:05:34.888169: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-25 17:05:34.892481: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-25 17:05:34.904391: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1732554334.923942 1927638 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1732554334.929865 1927638 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-25 17:05:34.952143: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
drichlet_ids = [1,2,5,6]
side_ids = []
invert_thwaites = Invert(outline = 'data/geojson/thwaites.geojson', mesh_name = 'thwaites', reg_constant_c  = 0.05, read_mesh = False,opts = None, drichlet_ids = drichlet_ids , lcar = 9e3)
# Out:
# Reading local outline
# Creating mesh
# Reading mesh
# Reading bedmachine data
# Initializing function spaces
# Initializing 3d function spaces
# Initializing fields
# Defining friction law
# Setting ramp power to :  1
# Initializing heat transport

# %%
invert_thwaites.plot_mesh()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='meters'>)

# %%
invert_thwaites.import_velocity_data(C = 'driving-stress')
invert_thwaites.import_geophysics_data(name_list=['data/geophysics/ADMAP_MagneticAnomaly_5km.tif', 
                                                'data/geophysics/ANTGG_BouguerAnomaly_10km.tif', 
                                                'data/geophysics/GeothermalHeatFlux_5km.tif',
                                                'data/geophysics/ALBMAP_SurfaceAirTemperature_5km.tif',
                                                'data/geophysics/EIGEN-6C4_GravityDisturbance_10km.tif',
                                                'data/geophysics/ALBMAP_SnowAccumulation_Arthern_5km.tif',
                                                'data/geophysics/Englacial_temp_Pattyn_2013.tif'])
# Out:
# Reading velocity from measures database
# C0 is computed using driving stress
# Defining friction law
# Defining friction law
# using englacial temperature for rate factor
# Geophysics data imported

# %%
invert_thwaites.plot_englacial_temp()
# Out:
# (<Figure size 640x480 with 2 Axes>,
#  <Axes: title={'center': 'Englacial Temperature'}, xlabel='meters'>)

# %%
invert_thwaites.plot_scalar_field(invert_thwaites.heatflux, title_name = 'Heatflux')
# Out:
# (<Figure size 640x480 with 2 Axes>,
#  <Axes: title={'center': 'Heatflux'}, xlabel='meters'>)

# %%
invert_thwaites.plot_scalar_field(invert_thwaites.surface_air_temp, title_name = 'Surface Air Temp')
# Out:
# (<Figure size 640x480 with 2 Axes>,
#  <Axes: title={'center': 'Surface Air Temp'}, xlabel='meters'>)

# %%
invert_thwaites.plot_scalar_field(invert_thwaites.gravity_disturbance, title_name = 'Gravity Disturbance')
# Out:
# (<Figure size 640x480 with 2 Axes>,
#  <Axes: title={'center': 'Gravity Disturbance'}, xlabel='meters'>)

# %%
invert_thwaites.plot_scalar_field(invert_thwaites.snow_accumulation, vmax = 10, title_name = 'Snow Accumulation')
# Out:
# (<Figure size 640x480 with 2 Axes>,
#  <Axes: title={'center': 'Snow Accumulation'}, xlabel='meters'>)

# %%
invert_thwaites.plot_surface()
# Out:
# (<Figure size 640x480 with 2 Axes>,
#  <Axes: title={'center': 'Surface elevation'}, xlabel='meters'>)

# %%
invert_thwaites.plot_thickness()
# Out:
# (<Figure size 640x480 with 2 Axes>,
#  <Axes: title={'center': 'Thickness'}, xlabel='meters'>)

# %%
invert_thwaites.plot_scalar_field(invert_thwaites.b, title_name = 'basal topography')
# Out:
# (<Figure size 640x480 with 2 Axes>,
#  <Axes: title={'center': 'basal topography'}, xlabel='meters'>)
